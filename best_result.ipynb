# %% [markdown]
# ### Import Packages

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import copy
import random
import torch.nn.functional as F
import time
import argparse
import datetime
import sys
from torch.utils.data import DataLoader
import math
from torch.optim import Adam
from torch.utils.tensorboard import SummaryWriter
import shutil
import hashlib
from torch import nn as nn
from torch.utils.data import Dataset
import os
from PIL import Image, ImageDraw

# %%
import sys
sys.path.append('./')
from dsetsFullCT import TrainingLuna2dSegmentationDataset, Luna2dSegmentationDataset, PrepcacheLunaDataset, getCt
from util import logging, enumerateWithEstimate
from UDet_3layer import UDet

# %% [markdown]
# # Model

# %%
class UNet(nn.Module):
    def __init__(self, in_channels=1, n_classes=2, depth=5, wf=6, padding=False,  #原論文channel數是64，為2^6
                 batch_norm=False, up_mode='upconv'):
        """
        Implementation of
        U-Net: Convolutional Networks for Biomedical Image Segmentation
        (Ronneberger et al., 2015)
        https://arxiv.org/abs/1505.04597

        Using the default arguments will yield the exact version used
        in the original paper

        Args:
            in_channels (int): number of input channels
            n_classes (int): number of output channels
            depth (int): depth of the network
            wf (int): number of filters in the first layer is 2**wf
            padding (bool): if True, apply padding such that the input shape
                            is the same as the output.
                            This may introduce artifacts
            batch_norm (bool): Use BatchNorm after layers with an
                               activation function
            up_mode (str): one of 'upconv' or 'upsample'.
                           'upconv' will use transposed convolutions for
                           learned upsampling.
                           'upsample' will use bilinear upsampling.
        """
        super(UNet, self).__init__()
        assert up_mode in ('upconv', 'upsample')
        self.padding = padding
        self.depth = depth
        prev_channels = in_channels
        self.down_path = nn.ModuleList()
        for i in range(depth):
            self.down_path.append(UNetConvBlock(prev_channels, 2**(wf+i),
                                                padding, batch_norm))
            prev_channels = 2**(wf+i)

        self.up_path = nn.ModuleList()
        for i in reversed(range(depth - 1)):
            self.up_path.append(UNetUpBlock(prev_channels, 2**(wf+i), up_mode,
                                            padding, batch_norm))
            prev_channels = 2**(wf+i) #channel數會隨著down sampling增加，以2的倍數增加

        self.last = nn.Conv2d(prev_channels, n_classes, kernel_size=1)

    def forward(self, x):
        blocks = []
        for i, down in enumerate(self.down_path):
            x = down(x)
            if i != len(self.down_path)-1:
                blocks.append(x)  #put the result in blocks, and to be a bridge to upsampleing
                x = F.avg_pool2d(x, 2)  #做一次的avarage pooling, stride為2, kernel size 為2(大小砍半)

        for i, up in enumerate(self.up_path):
            x = up(x, blocks[-i-1])

        return self.last(x)

class UNetConvBlock(nn.Module): #每一層都會做2次的convolution，kenrel size 都是3
    def __init__(self, in_size, out_size, padding, batch_norm):
        super(UNetConvBlock, self).__init__()
        block = []

        block.append(nn.Conv2d(in_size, out_size, kernel_size=3,
                               padding=int(padding)))
        block.append(nn.ReLU())
        # block.append(nn.LeakyReLU())
        if batch_norm:
            block.append(nn.BatchNorm2d(out_size))

        block.append(nn.Conv2d(out_size, out_size, kernel_size=3,
                               padding=int(padding)))
        block.append(nn.ReLU())
        # block.append(nn.LeakyReLU())
        if batch_norm:
            block.append(nn.BatchNorm2d(out_size))

        self.block = nn.Sequential(*block)

    def forward(self, x):
        out = self.block(x)
        return out

class UNetUpBlock(nn.Module):
    def __init__(self, in_size, out_size, up_mode, padding, batch_norm):
        super(UNetUpBlock, self).__init__()
        if up_mode == 'upconv':
            self.up = nn.ConvTranspose2d(in_size, out_size, kernel_size=2,
                                         stride=2)
        elif up_mode == 'upsample':
            self.up = nn.Sequential(nn.Upsample(mode='bilinear', scale_factor=2),
                                    nn.Conv2d(in_size, out_size, kernel_size=1))

        self.conv_block = UNetConvBlock(in_size, out_size, padding, batch_norm)

    def center_crop(self, layer, target_size):
        _, _, layer_height, layer_width = layer.size()
        diff_y = (layer_height - target_size[0]) // 2
        diff_x = (layer_width - target_size[1]) // 2
        return layer[:, :, diff_y:(diff_y + target_size[0]), diff_x:(diff_x + target_size[1])]

    def forward(self, x, bridge):
        up = self.up(x)
        crop1 = self.center_crop(bridge, up.shape[2:])
        out = torch.cat([up, crop1], 1)
        out = self.conv_block(out)

        return out

# %%
class UNetWrapper(nn.Module):
    def __init__(self, **kwargs): #kwarg is a dictionary containing all keyword arguments passed to the constructor
        super().__init__()

        # we will do batchnormalization first 
        self.input_batchnorm = nn.BatchNorm2d(kwargs['in_channels'])  #in kwarg, we have in_channels params to give the input channel
        self.unet = UNet(**kwargs)
        self.final = nn.Sigmoid() #use sigmoid to limit the output to 0,1

        self._init_weights()

    def _init_weights(self):
        init_set = {
            nn.Conv2d,
            nn.Conv3d,
            nn.ConvTranspose2d,
            nn.ConvTranspose3d,
            nn.Linear,
        }
        for m in self.modules():
            if type(m) in init_set:
                nn.init.kaiming_normal_(
                    m.weight.data, mode='fan_out', nonlinearity='relu', a=0
                )
                if m.bias is not None:
                    fan_in, fan_out = \
                        nn.init._calculate_fan_in_and_fan_out(m.weight.data)
                    bound = 1 / math.sqrt(fan_out)
                    nn.init.normal_(m.bias, -bound, bound)

        # nn.init.constant_(self.unet.last.bias, -4)
        # nn.init.constant_(self.unet.last.bias, 4)


    def forward(self, input_batch):
        bn_output = self.input_batchnorm(input_batch)
        un_output = self.unet(bn_output)
        fn_output = self.final(un_output)
        return fn_output
    
class UDetWrapper(nn.Module):
    def __init__(self, **kwargs): #kwarg is a dictionary containing all keyword arguments passed to the constructor
        super().__init__()

        # we will do batchnormalization first 
        self.input_batchnorm = nn.BatchNorm2d(kwargs['in_channels'])  #in kwarg, we have in_channels params to give the input channel
        self.udet = UDet(**kwargs)
        self.final = nn.Sigmoid() #use sigmoid to limit the output to 0,1

        self._init_weights()

    def _init_weights(self):
        init_set = {
            nn.Conv2d,
            nn.Conv3d,
            nn.ConvTranspose2d,
            nn.ConvTranspose3d,
            nn.Linear,
        }
        for m in self.modules():
            if type(m) in init_set:
                nn.init.kaiming_normal_(
                    m.weight.data, mode='fan_out', nonlinearity='relu', a=0
                )
                if m.bias is not None:
                    fan_in, fan_out = \
                        nn.init._calculate_fan_in_and_fan_out(m.weight.data)
                    bound = 1 / math.sqrt(fan_out)
                    nn.init.normal_(m.bias, -bound, bound)

        # nn.init.constant_(self.unet.last.bias, -4)
        # nn.init.constant_(self.unet.last.bias, 4)


    def forward(self, input_batch):
        bn_output = self.input_batchnorm(input_batch)
        un_output = self.udet(bn_output)
        fn_output = self.final(un_output)
        return fn_output

class SegmentationAugmentation(nn.Module):
    def __init__(
            self, flip=None, offset=None, scale=None, rotate=None, noise=None
    ):
        super().__init__()

        self.flip = flip
        self.offset = offset
        self.scale = scale
        self.rotate = rotate
        self.noise = noise

    def forward(self, input_g, label_g):
        transform_t = self._build2dTransformMatrix()
        transform_t = transform_t.expand(input_g.shape[0], -1, -1)  #對Index複製
        transform_t = transform_t.to(input_g.device, torch.float32) #transform前兩行有關伸縮旋轉，最後一行有關平移
        affine_t = F.affine_grid(transform_t[:,:2],
                input_g.size(), align_corners=False)  #使用affine grid的原因是因為用grid可以減少對整張圖的運算量
                                     #而且如果用原圖，可能會造成座標落在非整數格上，如此會讓圖型產生矩齒狀

        augmented_input_g = F.grid_sample(input_g,
                affine_t, padding_mode='border',
                align_corners=False)
        augmented_label_g = F.grid_sample(label_g.to(torch.float32),#grid sample只吃float，所以這裡轉float，但用同一個affine grid
                affine_t, padding_mode='border',
                align_corners=False)

        if self.noise:
            noise_t = torch.randn_like(augmented_input_g)
            noise_t *= self.noise

            augmented_input_g += noise_t

        return augmented_input_g, augmented_label_g > 0.5 #把label改回成0,1

    def _build2dTransformMatrix(self):
        transform_t = torch.eye(3)  #建立一個3*3單位矩陣

        for i in range(2):  #我們只有2D
            if self.flip:
                if random.random() > 0.5:
                    transform_t[i,i] *= -1

            if self.offset:
                offset_float = self.offset
                random_float = (random.random() * 2 - 1)
                transform_t[2,i] = offset_float * random_float

            if self.scale:
                scale_float = self.scale
                random_float = (random.random() * 2 - 1)
                transform_t[i,i] *= 1.0 + scale_float * random_float

        if self.rotate:
            angle_rad = random.random() * math.pi * 2 #隨機弧度
            s = math.sin(angle_rad) #轉角度
            c = math.cos(angle_rad)

            rotation_t = torch.tensor([
                [c, -s, 0],
                [s, c, 0],
                [0, 0, 1]])

            transform_t @= rotation_t #矩陣乘法

        return transform_t

# %% [markdown]
# # Prepcache

# %%
class LunaPrepCacheApp:
    @classmethod
    def __init__(self, sys_argv=None):
        if sys_argv is None:
            sys_argv = sys.argv[1:]

        parser = argparse.ArgumentParser()
        parser.add_argument('--batch-size',
            help='Batch size to use for training',
            default=1024,
            type=int,
        )
        parser.add_argument('--num-workers',
            help='Number of worker processes for background data loading',
            default=1, #8
            type=int,
        )
        # parser.add_argument('--scaled',
        #     help="Scale the CT chunks to square voxels.",
        #     default=False,
        #     action='store_true',
        # )

        self.cli_args = parser.parse_args(sys_argv)

    def main(self):
        log.info("Starting {}, {}".format(type(self).__name__, self.cli_args))

        self.prep_dl = DataLoader(
             PrepcacheLunaDataset(
#                 # sortby_str='series_uid',
             ),
   
            batch_size=self.cli_args.batch_size,
            num_workers=self.cli_args.num_workers,
        )

        batch_iter = enumerateWithEstimate(
            self.prep_dl,
            "Stuffing cache",
            start_ndx=self.prep_dl.num_workers,
        )
        for batch_ndx, batch_tup in batch_iter:
            pass

# %% [markdown]
# # Training

# %%
class DiceLoss(nn.Module):
    def __init__(self):
        super(DiceLoss, self).__init__()
        self.epsilon = 1e-5
    
    def forward(self, predict, target):
        assert predict.size() == target.size(), "the size of predict and target must be equal."
        num = predict.size(0)
        
        pre = torch.sigmoid(predict).view(num, -1)
        tar = target.view(num, -1)
        
        intersection = (pre * tar).sum(-1).sum()  #利用预测值与标签相乘当作交集
        union = (pre + tar).sum(-1).sum()
        
        score = 1 - 2 * (intersection + self.epsilon) / (union + self.epsilon)
        
        return score

# %%
log = logging.getLogger(__name__)
# log.setLevel(logging.WARN)
# log.setLevel(logging.INFO)
log.setLevel(logging.DEBUG)
METRICS_LOSS_NDX = 1
METRICS_TP_NDX = 7
METRICS_FN_NDX = 8
METRICS_FP_NDX = 9

METRICS_SIZE = 10
class SegmentationTrainingApp:
    def __init__(self, sys_argv=None):
        if sys_argv is None:
            sys_argv = sys.argv[1:]

        parser = argparse.ArgumentParser()
        parser.add_argument('--batch-size',
            help='Batch size to use for training',
            default=16,
            type=int,
        )
        parser.add_argument('--num-workers',
            help='Number of worker processes for background data loading',
            default=8,
            type=int,
        )
        parser.add_argument('--epochs',
            help='Number of epochs to train for',
            default=1,
            type=int,
        )

        parser.add_argument('--augmented',
            help="Augment the training data.",
            action='store_true',
            default=False,
        )
        parser.add_argument('--augment-flip',
            help="Augment the training data by randomly flipping the data left-right, up-down, and front-back.",
            action='store_true',
            default=False,
        )
        parser.add_argument('--augment-offset',
            help="Augment the training data by randomly offsetting the data slightly along the X and Y axes.",
            action='store_true',
            default=False,
        )
        parser.add_argument('--augment-scale',
            help="Augment the training data by randomly increasing or decreasing the size of the candidate.",
            action='store_true',
            default=False,
        )
        parser.add_argument('--augment-rotate',
            help="Augment the training data by randomly rotating the data around the head-foot axis.",
            action='store_true',
            default=False,
        )
        parser.add_argument('--augment-noise',
            help="Augment the training data by randomly adding noise to the data.",
            action='store_true',
            default=False,
        )

        parser.add_argument('--tb-prefix',
            default='udet',
            help="Data prefix to use for Tensorboard run. Defaults to chapter.",
        )

        parser.add_argument('comment',
            help="Comment suffix for Tensorboard run.",
            nargs='?',
            default='none',
        )

        self.cli_args = parser.parse_args(sys_argv)
        self.time_str = datetime.datetime.now().strftime('%Y-%m-%d_%H.%M.%S')
        self.totalTrainingSamples_count = 0
        self.trn_writer = None
        self.val_writer = None

        #augumentation設定的值
        self.augmentation_dict = {}
        if self.cli_args.augmented or self.cli_args.augment_flip:
            self.augmentation_dict['flip'] = True
        if self.cli_args.augmented or self.cli_args.augment_offset:
            self.augmentation_dict['offset'] = 0.03
        if self.cli_args.augmented or self.cli_args.augment_scale:
            self.augmentation_dict['scale'] = 0.2
        if self.cli_args.augmented or self.cli_args.augment_rotate:
            self.augmentation_dict['rotate'] = True
        if self.cli_args.augmented or self.cli_args.augment_noise:
            self.augmentation_dict['noise'] = 25.0

        self.use_cuda = torch.cuda.is_available()
        self.device = torch.device("cuda" if self.use_cuda else "cpu")

        self.segmentation_model, self.augmentation_model = self.initModel()
        self.optimizer = self.initOptimizer()


    def initModel(self):
        segmentation_model = UDetWrapper(
            in_channels=7,
            n_classes=1,
            depth=2,  #how deep the U go
            wf=6,   #2^4 filter
            padding=True, #padding so that we get the output size as input size
            batch_norm=True,
            up_mode='upconv', #use  nn.ConvTranspose2d
        )

        augmentation_model = SegmentationAugmentation(**self.augmentation_dict)

        if self.use_cuda:
            log.info("Using CUDA; {} devices.".format(torch.cuda.device_count()))
            if torch.cuda.device_count() > 1: #parallel data if we have much device
                segmentation_model = nn.DataParallel(segmentation_model)
                augmentation_model = nn.DataParallel(augmentation_model)
            segmentation_model = segmentation_model.to(self.device)
            augmentation_model = augmentation_model.to(self.device)

        return segmentation_model, augmentation_model #回傳unet wrapper和augmentation

    def initOptimizer(self):
        return Adam(self.segmentation_model.parameters(), lr=0.001, betas=(0.99,0.999), weight_decay=1e-6)
        # return SGD(self.segmentation_model.parameters(), lr=0.001, momentum=0.99)


    def initTrainDl(self):
        train_ds = TrainingLuna2dSegmentationDataset(
            val_stride=10,
            isValSet_bool=False,
            contextSlices_count=3,
        )

        batch_size = self.cli_args.batch_size
        if self.use_cuda:
            batch_size *= torch.cuda.device_count()

        train_dl = DataLoader(
            train_ds,
            batch_size=batch_size,
            num_workers=self.cli_args.num_workers,
            pin_memory=self.use_cuda,
        )

        return train_dl

    def initValDl(self):
        val_ds = Luna2dSegmentationDataset(
            val_stride=10,
            isValSet_bool=True,
            contextSlices_count=3,
        )

        batch_size = self.cli_args.batch_size
        if self.use_cuda:
            batch_size *= torch.cuda.device_count()

        val_dl = DataLoader(
            val_ds,
            batch_size=batch_size,
            num_workers=self.cli_args.num_workers,
            pin_memory=self.use_cuda,
        )

        return val_dl

    def initTensorboardWriters(self):
        if self.trn_writer is None:
            log_dir = os.path.join('runs', self.cli_args.tb_prefix, self.time_str)

            self.trn_writer = SummaryWriter(
                log_dir=log_dir + '_trn_seg_' + self.cli_args.comment)
            self.val_writer = SummaryWriter(
                log_dir=log_dir + '_val_seg_' + self.cli_args.comment)

    def main(self):
        log.info("Starting {}, {}".format(type(self).__name__, self.cli_args))

        train_dl = self.initTrainDl()
        val_dl = self.initValDl()

        best_score = 0.0
        self.validation_cadence = 5
        for epoch_ndx in range(1, self.cli_args.epochs + 1):
            log.info("Epoch {} of {}, {}/{} batches of size {}*{}".format(
                epoch_ndx,
                self.cli_args.epochs,
                len(train_dl),
                len(val_dl),
                self.cli_args.batch_size,
                (torch.cuda.device_count() if self.use_cuda else 1),
            ))

            trnMetrics_t = self.doTraining(epoch_ndx, train_dl)
            self.logMetrics(epoch_ndx, 'trn', trnMetrics_t)

            if epoch_ndx == 1 or epoch_ndx % self.validation_cadence == 0:
                # if validation is wanted
                valMetrics_t = self.doValidation(epoch_ndx, val_dl)
                score = self.logMetrics(epoch_ndx, 'val', valMetrics_t)
                best_score = max(score, best_score)

                self.saveModel('seg', epoch_ndx, score == best_score)

                self.logImages(epoch_ndx, 'trn', train_dl)
                self.logImages(epoch_ndx, 'val', val_dl)

        self.trn_writer.close()
        self.val_writer.close()

    def doTraining(self, epoch_ndx, train_dl):
        trnMetrics_g = torch.zeros(METRICS_SIZE, len(train_dl.dataset), device=self.device)
        self.segmentation_model.train()
        train_dl.dataset.shuffleSamples()

        batch_iter = enumerateWithEstimate(
            train_dl,
            "E{} Training".format(epoch_ndx),
            start_ndx=train_dl.num_workers,
        )
        for batch_ndx, batch_tup in batch_iter:
            self.optimizer.zero_grad()

            loss_var = self.computeBatchLoss(batch_ndx, batch_tup, train_dl.batch_size, trnMetrics_g)
            loss_var.backward()

            self.optimizer.step()

        self.totalTrainingSamples_count += trnMetrics_g.size(1)

        return trnMetrics_g.to('cpu')

    def doValidation(self, epoch_ndx, val_dl):
        with torch.no_grad():
            valMetrics_g = torch.zeros(METRICS_SIZE, len(val_dl.dataset), device=self.device)
            self.segmentation_model.eval()
            batch_iter = enumerateWithEstimate(
                val_dl,
                "E{} Validation ".format(epoch_ndx),
                start_ndx=val_dl.num_workers,
            )
            for batch_ndx, batch_tup in batch_iter:
                self.computeBatchLoss(batch_ndx, batch_tup, val_dl.batch_size, valMetrics_g)

        return valMetrics_g.to('cpu')

    def computeBatchLoss(self, batch_ndx, batch_tup, batch_size, metrics_g,
                         classificationThreshold=0.5):
        input_t, label_t, series_list, _slice_ndx_list = batch_tup

        input_g = input_t.to(self.device, non_blocking=True)
        label_g = label_t.to(self.device, non_blocking=True)

        if self.segmentation_model.training and self.augmentation_dict:
            input_g, label_g = self.augmentation_model(input_g, label_g)

        prediction_g = self.segmentation_model(input_g)
        
        pos_weight = torch.tensor([1000.0]).to(self.device, non_blocking=True)
        
        
        # loss = DiceLoss()
        # DLoss = criterion(prediction_g, label_g.to(torch.float))
        criterion = torch.nn.BCEWithLogitsLoss(pos_weight=pos_weight)
        BCELoss = criterion(prediction_g, label_g.to(torch.float))
        # fnLoss_g = criterion(prediction_g * ~label_g, label_g.to(torch.float))
        # print(BCELoss)

        # diceLoss_g = self.diceLoss(prediction_g, label_g)
        # fnLoss_g = self.diceLoss(prediction_g * label_g, label_g) #只關心ground truth為true的部分
#         # print(diceLoss_g.mean())
#         # print(fnLoss_g)
#         # print(diceLoss_g + fnLoss_g * 8)
#         # print()

        start_ndx = batch_ndx * batch_size
        end_ndx = start_ndx + input_t.size(0)

        with torch.no_grad():
            predictionBool_g = (prediction_g[:, 0:1]
                                > classificationThreshold).to(torch.float32)

            tp = (     predictionBool_g *  label_g).sum(dim=[1,2,3])
            fn = ((1 - predictionBool_g) *  label_g).sum(dim=[1,2,3])
            fp = (     predictionBool_g * (~label_g)).sum(dim=[1,2,3])

            metrics_g[METRICS_LOSS_NDX, start_ndx:end_ndx] = BCELoss
            # metrics_g[METRICS_LOSS_NDX, start_ndx:end_ndx] = diceLoss_g + fnLoss_g * 8
            metrics_g[METRICS_TP_NDX, start_ndx:end_ndx] = tp
            metrics_g[METRICS_FN_NDX, start_ndx:end_ndx] = fn
            metrics_g[METRICS_FP_NDX, start_ndx:end_ndx] = fp
        return BCELoss
        # return BCELoss
            
        # return diceLoss_g.mean()

        # return diceLoss_g.mean() + fnLoss_g.mean() * 8  #loss 的權重:positive pixel是negative的8倍, we should expect a large number of false positives in general
        

    def diceLoss(self, prediction_g, label_g, epsilon=1): #如果大部分的pixel是false，用dice會比較精準
        diceLabel_g = label_g.sum(dim=[1,2,3])  #將所有mask裡計為nodule的點加起來(我們的dataset是4維, 後3維是index, row, column)
        dicePrediction_g = prediction_g.sum(dim=[1,2,3])
        diceCorrect_g = (prediction_g * label_g).sum(dim=[1,2,3]) #預測正確的總量

        diceRatio_g = (2 * diceCorrect_g + epsilon) \
            / (dicePrediction_g + diceLabel_g + epsilon)  #epsilon避免其值為0

        return 1 - diceRatio_g  #為了最小化，要用1去扣


    def logImages(self, epoch_ndx, mode_str, dl):
        self.segmentation_model.eval()

        images = sorted(dl.dataset.series_list)[:12]
        for series_ndx, series_uid in enumerate(images):
            ct = getCt(series_uid)

            for slice_ndx in range(6):
                ct_ndx = slice_ndx * (ct.hu_a.shape[0] - 1) // 5
                sample_tup = dl.dataset.getitem_fullSlice(series_uid, ct_ndx)

                ct_t, label_t, series_uid, ct_ndx = sample_tup

                input_g = ct_t.to(self.device).unsqueeze(0)
                label_g = pos_g = label_t.to(self.device).unsqueeze(0)

                prediction_g = self.segmentation_model(input_g)[0]
                prediction_a = prediction_g.to('cpu').detach().numpy()[0] > 0.5
                label_a = label_g.cpu().numpy()[0][0] > 0.5

                ct_t[:-1,:,:] /= 2000
                ct_t[:-1,:,:] += 0.5

                ctSlice_a = ct_t[dl.dataset.contextSlices_count].numpy()

                image_a = np.zeros((512, 512, 3), dtype=np.float32)
                image_a[:,:,:] = ctSlice_a.reshape((512,512,1))
                image_a[:,:,0] += prediction_a & (1 - label_a)
                image_a[:,:,0] += (1 - prediction_a) & label_a
                image_a[:,:,1] += ((1 - prediction_a) & label_a) * 0.5

                image_a[:,:,1] += prediction_a & label_a
                image_a *= 0.5
                image_a.clip(0, 1, image_a)

                writer = getattr(self, mode_str + '_writer')
                writer.add_image(
                    f'{mode_str}/{series_ndx}_prediction_{slice_ndx}',
                    image_a,
                    self.totalTrainingSamples_count,
                    dataformats='HWC',
                )

                if epoch_ndx == 1:
                    image_a = np.zeros((512, 512, 3), dtype=np.float32)
                    image_a[:,:,:] = ctSlice_a.reshape((512,512,1))
                    # image_a[:,:,0] += (1 - label_a) & lung_a # Red
                    image_a[:,:,1] += label_a  # Green
                    # image_a[:,:,2] += neg_a  # Blue

                    image_a *= 0.5
                    image_a[image_a < 0] = 0
                    image_a[image_a > 1] = 1
                    writer.add_image(
                        '{}/{}_label_{}'.format(
                            mode_str,
                            series_ndx,
                            slice_ndx,
                        ),
                        image_a,
                        self.totalTrainingSamples_count,
                        dataformats='HWC',
                    )
                # This flush prevents TB from getting confused about which
                # data item belongs where.
                writer.flush()

    def logMetrics(self, epoch_ndx, mode_str, metrics_t):
        log.info("E{} {}".format(
            epoch_ndx,
            type(self).__name__,
        ))

        metrics_a = metrics_t.detach().numpy()
        sum_a = metrics_a.sum(axis=1)
        assert np.isfinite(metrics_a).all()

        allLabel_count = sum_a[METRICS_TP_NDX] + sum_a[METRICS_FN_NDX]

        metrics_dict = {}
        metrics_dict['loss/all'] = metrics_a[METRICS_LOSS_NDX].mean()

        metrics_dict['percent_all/tp'] = \
            sum_a[METRICS_TP_NDX] / (allLabel_count or 1) * 100
        metrics_dict['percent_all/fn'] = \
            sum_a[METRICS_FN_NDX] / (allLabel_count or 1) * 100
        metrics_dict['percent_all/fp'] = \
            sum_a[METRICS_FP_NDX] / (allLabel_count or 1) * 100


        precision = metrics_dict['pr/precision'] = sum_a[METRICS_TP_NDX] \
            / ((sum_a[METRICS_TP_NDX] + sum_a[METRICS_FP_NDX]) or 1)
        recall    = metrics_dict['pr/recall']    = sum_a[METRICS_TP_NDX] \
            / ((sum_a[METRICS_TP_NDX] + sum_a[METRICS_FN_NDX]) or 1)

        metrics_dict['pr/f1_score'] = 2 * (precision * recall) \
            / ((precision + recall) or 1)

        log.info(("E{} {:8} "
                 + "{loss/all:.4f} loss, "
                 + "{pr/precision:.4f} precision, "
                 + "{pr/recall:.4f} recall, "
                 + "{pr/f1_score:.4f} f1 score"
                  ).format(
            epoch_ndx,
            mode_str,
            **metrics_dict,
        ))
        log.info(("E{} {:8} "
                  + "{loss/all:.4f} loss, "
                  + "{percent_all/tp:-5.1f}% tp, {percent_all/fn:-5.1f}% fn, {percent_all/fp:-9.1f}% fp"
        ).format(
            epoch_ndx,
            mode_str + '_all',
            **metrics_dict,
        ))

        self.initTensorboardWriters()
        writer = getattr(self, mode_str + '_writer')

        prefix_str = 'seg_'

        for key, value in metrics_dict.items():
            writer.add_scalar(prefix_str + key, value, self.totalTrainingSamples_count)

        writer.flush()

        score = metrics_dict['pr/recall']

        return score

    def saveModel(self, type_str, epoch_ndx, isBest=False):
        file_path = os.path.join(
            'models',
            self.cli_args.tb_prefix,
            '{}_{}_{}.{}.state'.format(
                type_str,
                self.time_str,
                self.cli_args.comment,
                self.totalTrainingSamples_count,
            )
        )

        os.makedirs(os.path.dirname(file_path), mode=0o755, exist_ok=True)

        model = self.segmentation_model
        if isinstance(model, torch.nn.DataParallel):
            model = model.module

        state = {
            'sys_argv': sys.argv,
            'time': str(datetime.datetime.now()),
            'model_state': model.state_dict(),
            'model_name': type(model).__name__,
            'optimizer_state' : self.optimizer.state_dict(),
            'optimizer_name': type(self.optimizer).__name__,
            'epoch': epoch_ndx,
            'totalTrainingSamples_count': self.totalTrainingSamples_count,
        }
        torch.save(state, file_path)

        log.info("Saved model params to {}".format(file_path))

        if isBest:
            best_path = os.path.join(
               'models',
                self.cli_args.tb_prefix,
                f'{type_str}_{self.time_str}_{self.cli_args.comment}.best.state')
            shutil.copyfile(file_path, best_path)

            log.info("Saved model params to {}".format(best_path))

        with open(file_path, 'rb') as f:
            log.info("SHA1: " + hashlib.sha1(f.read()).hexdigest())

# %%
# train_ds = TrainingLuna2dSegmentationDataset(
#             val_stride=10,
#             isValSet_bool=False,
#             contextSlices_count=2,
#         )
# # print(len(train_ds))
# total_rate = 0
# total = (512 * 512)
# i = 0
# average_rate = 0
# for i in range(8001):
#     # if (i % 10 == 0):
#     #     # print("i = ", i)
#     #     average_rate += (total_rate) / 10
#     #     # print("avg = ", average_rate)
#     #     total_rate = 0
#     if (i % 1000 == 0):
#         print("i = ", i)
#         print("avg = ", average_rate)
#     i += 1
#     csum = (train_ds[i][1].sum())
#     # print("sum = ", csum)
#     total_rate += csum / total
# average_rate = (total_rate) / 8000
# print(average_rate)

# %%
# LunaPrepCacheApp(sys_argv=["--num-workers=4"]).main()

# %%
# torch.autograd.set_detect_anomaly(False)

# %%
# import pandas as pd
# import glob
# import SimpleITK as sitk
# import numpy as np
# import collections
# from PIL import Image, ImageDraw

# train_ds = TrainingLuna2dSegmentationDataset(
#             series_uid="1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860"
#         )
# hu_a = train_ds[0][0].numpy()
# hu_mask = train_ds[0][1].numpy().astype(int)
# print(hu_a.shape)
# print(hu_mask.shape)
# min_value = np.min(hu_a[3])
# max_value = np.max(hu_a[3])
# scaled_hu_a = (hu_a[3] - min_value) / (max_value - min_value) * 255
# scaled_hu_a = scaled_hu_a.astype(np.uint8)
# slice_ori = Image.fromarray(scaled_hu_a, mode='L')
# slice_ori.save("origin.png")
# min_value_mask = np.min(hu_mask[0])
# max_value_mask = np.max(hu_mask[0])
# # print(min_value_mask)
# # print(max_value_mask)
# scaled_mask = hu_mask[0] * 255
# slice_mask = Image.fromarray(scaled_mask, mode='L')
# slice_mask.save("mask.png")

# %%
# train_ds = TrainingLuna2dSegmentationDataset(
#             series_uid="1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860"
#         )
# print(train_ds[0][2])

# %%
# ct_slice = Image.fromarray(scaled_hu_a, mode='L')

# # Create a drawing context on the image
# draw = ImageDraw.Draw(ct_slice)

# # Define the coordinates to mark (row 212, column 45) as a red rectangle
# x1, y1, x2, y2 = 44, 211, 46, 213  # Adjust these coordinates as needed

# # Define the outline color as "red"
# outline_color = (0, 0, 255)  # Use grayscale value 255 for white outline

# # Draw a red rectangle on the image to mark the specific row and column
# draw.rectangle([x1, y1, x2, y2], outline="white", width=3)  # Increase width for better visibility

# # Save the marked slice as a PNG
# ct_slice.save("marked_slice.png")

# %%
def np2Png(np_arr, target_name):
    min_value = np.min(np_arr[0])
    max_value = np.max(np_arr[0])
    scaled_np_arr = (np_arr[0] - min_value) / (max_value - min_value) * 255
    scaled_np_arr = scaled_np_arr.astype(np.uint8)
    slice_ori = Image.fromarray(scaled_np_arr, mode='L')
    slice_ori.save(target_name)

# %%
# segmentation_model = UNetWrapper(
#             in_channels=7,
#             n_classes=1,
#             depth=2,  #how deep the U go
#             wf=6,   #2^4 filter
#             padding=True, #padding so that we get the output size as input size
#             batch_norm=True,
#             up_mode='upconv', #use  nn.ConvTranspose2d
#         )
# # model_state
# # torch.load("F:\\udet\\models\\udet\\seg_2023-10-19_08.28.18_final-cls.best.state")["model_state"]
# segmentation_model.load_state_dict(torch.load("F:\\udet\\models\\udet\\u_net_depth2_200epcoch_f1score0.2.state")["model_state"])
# device = torch.device("cuda")
# segmentation_model.to(device)
# segmentation_model.eval()
# val_ds = Luna2dSegmentationDataset(
#             val_stride=10,
#             isValSet_bool=True,
#             contextSlices_count=3,
#         )

# batch_size = 8

# val_dl = DataLoader(
#     val_ds,
#     batch_size=batch_size,
#     num_workers=4,
#     pin_memory=True,
# )
# batch_iter = enumerateWithEstimate(
#     val_dl,
#     "E{} Validation ".format(1),
#     start_ndx=val_dl.num_workers,
# )

# %%
# for batch_ndx, batch_tup in batch_iter:
#     input_t, label_t, series_list, _slice_ndx_list = batch_tup

#     input_g = input_t.to(device, non_blocking=True)
#     label_g = label_t.to(device, non_blocking=True)

#     prediction_g = segmentation_model(input_g)
#     # np2Png(input_g.cpu().numpy().astype(int), "./test/test.png")
#     # np2Png(label_g.cpu().numpy().astype(int), "./test/label.png")
#     # np2Png(prediction_g.cpu().detach().numpy().astype(float), "./test/predict.png")
#     break

# %%
val_ds = Luna2dSegmentationDataset(
            val_stride=1,
            isValSet_bool=True,
            contextSlices_count=0,
        )
print(len(val_ds))

# %%
val_ds[2]

# %%
print(val_ds[0][0].size())

# %%
# for i in range(len(val_ds)):
#     origin_n = val_ds[i][0].numpy()
#     mask_n = val_ds[i][1].numpy()
#     mask_ori_n = ((val_ds[i][0].float() + 1001) * val_ds[i][1]).numpy()
#     # print(type(origin_n[0]))
#     np2Png(origin_n.astype(int), "./origin_new/{}_{}_{}.png".format(i, val_ds[i][2], val_ds[i][3]))
#     np2Png(mask_n.astype(int), "./mask_new/{}_{}_{}.png".format(i, val_ds[i][2], val_ds[i][3]))
#     np2Png(mask_ori_n.astype(int), "./mask_origin_new/{}_{}_{}.png".format(i, val_ds[i][2], val_ds[i][3]))

# %%
# origin_n = input_g.cpu().numpy()
# np2Png(origin_n[0].astype(int), "./test/test.png")

# %%
# prediction_g.size()
# label_g.size()
# label_n = label_g.cpu().numpy()
# np2Png(label_n[0].astype(int), "./test/label.png")

# %%
# prediction_n = prediction_g.cpu().detach().numpy()
# np2Png(prediction_n[0].astype(float), "./test/predict.png")

# %%
# np.sum(prediction_n)

# %%
# print(prediction_n)

# %%
# torch.cuda.is_available()

# %%
SegmentationTrainingApp(sys_argv=['--epochs=400','--augmented', 'final-cls',"--num-workers=8", "--batch-size=8"]).main()
# Out:
# 2023-10-22 20:26:07,000 INFO     pid:6164 __main__:115:initModel Using CUDA; 1 devices.
# 2023-10-22 20:26:07,073 INFO     pid:6164 __main__:179:main Starting SegmentationTrainingApp, Namespace(batch_size=8, num_workers=8, epochs=400, augmented=True, augment_flip=False, augment_offset=False, augment_scale=False, augment_rotate=False, augment_noise=False, tb_prefix='udet', comment='final-cls')
# 2023-10-22 20:26:10,023 INFO     pid:6164 dsetsFullCT:333:__init__ <dsetsFullCT.TrainingLuna2dSegmentationDataset object at 0x000001783E4026D0>: 80 training series, 1622 slices, 101 nodules
# 2023-10-22 20:26:10,047 INFO     pid:6164 dsetsFullCT:333:__init__ <dsetsFullCT.Luna2dSegmentationDataset object at 0x000001783E43E610>: 9 validation series, 131 slices, 11 nodules
# 2023-10-22 20:26:10,048 INFO     pid:6164 __main__:187:main Epoch 1 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:26:10,961 WARNING  pid:6164 util:109:enumerateWithEstimate E1 Training ----/203, starting
# 2023-10-22 20:26:35,104 INFO     pid:6164 util:126:enumerateWithEstimate E1 Training   64/203, done at 2023-10-22 20:26:55, 0:00:29
# 2023-10-22 20:26:57,129 WARNING  pid:6164 util:139:enumerateWithEstimate E1 Training ----/203, done at 2023-10-22 20:26:57
# 2023-10-22 20:26:57,131 INFO     pid:6164 __main__:381:logMetrics E1 SegmentationTrainingApp
# 2023-10-22 20:26:57,131 INFO     pid:6164 __main__:411:logMetrics E1 trn      1.2310 loss, 0.0051 precision, 0.8683 recall, 0.0102 f1 score
# 2023-10-22 20:26:57,133 INFO     pid:6164 __main__:421:logMetrics E1 trn_all  1.2310 loss,  86.8% tp,  13.2% fn,   16821.0% fp
# 2023-10-22 20:26:57,138 WARNING  pid:6164 util:109:enumerateWithEstimate E1 Validation  ----/17, starting
# 2023-10-22 20:27:20,176 INFO     pid:6164 util:126:enumerateWithEstimate E1 Validation    16/17, done at 2023-10-22 20:27:20, 0:00:03
# 2023-10-22 20:27:20,976 WARNING  pid:6164 util:139:enumerateWithEstimate E1 Validation  ----/17, done at 2023-10-22 20:27:20
# 2023-10-22 20:27:20,976 INFO     pid:6164 __main__:381:logMetrics E1 SegmentationTrainingApp
# 2023-10-22 20:27:20,976 INFO     pid:6164 __main__:411:logMetrics E1 val      1.1498 loss, 0.0031 precision, 0.9714 recall, 0.0063 f1 score
# 2023-10-22 20:27:20,984 INFO     pid:6164 __main__:421:logMetrics E1 val_all  1.1498 loss,  97.1% tp,   2.9% fn,   30800.0% fp
# 2023-10-22 20:27:21,003 INFO     pid:6164 __main__:474:saveModel Saved model params to models\udet\seg_2023-10-22_20.26.06_final-cls.1622.state
# 2023-10-22 20:27:21,018 INFO     pid:6164 __main__:483:saveModel Saved model params to models\udet\seg_2023-10-22_20.26.06_final-cls.best.state
# 2023-10-22 20:27:21,022 INFO     pid:6164 __main__:486:saveModel SHA1: 0114ec0c292d615761713c930d461771c12fa0c2
# 2023-10-22 20:29:00,539 INFO     pid:6164 __main__:187:main Epoch 2 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:29:00,567 WARNING  pid:6164 util:109:enumerateWithEstimate E2 Training ----/203, starting
# 2023-10-22 20:29:22,771 INFO     pid:6164 util:126:enumerateWithEstimate E2 Training   64/203, done at 2023-10-22 20:29:44, 0:00:30
# 2023-10-22 20:29:44,769 WARNING  pid:6164 util:139:enumerateWithEstimate E2 Training ----/203, done at 2023-10-22 20:29:44
# 2023-10-22 20:29:44,785 INFO     pid:6164 __main__:381:logMetrics E2 SegmentationTrainingApp
# 2023-10-22 20:29:44,785 INFO     pid:6164 __main__:411:logMetrics E2 trn      1.1947 loss, 0.0086 precision, 0.8292 recall, 0.0170 f1 score
# 2023-10-22 20:29:44,785 INFO     pid:6164 __main__:421:logMetrics E2 trn_all  1.1947 loss,  82.9% tp,  17.1% fn,    9562.3% fp
# 2023-10-22 20:29:44,787 INFO     pid:6164 __main__:187:main Epoch 3 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:29:44,812 WARNING  pid:6164 util:109:enumerateWithEstimate E3 Training ----/203, starting
# 2023-10-22 20:30:06,760 INFO     pid:6164 util:126:enumerateWithEstimate E3 Training   64/203, done at 2023-10-22 20:30:28, 0:00:30
# 2023-10-22 20:30:28,755 WARNING  pid:6164 util:139:enumerateWithEstimate E3 Training ----/203, done at 2023-10-22 20:30:28
# 2023-10-22 20:30:28,755 INFO     pid:6164 __main__:381:logMetrics E3 SegmentationTrainingApp
# 2023-10-22 20:30:28,755 INFO     pid:6164 __main__:411:logMetrics E3 trn      1.1677 loss, 0.0108 precision, 0.8391 recall, 0.0212 f1 score
# 2023-10-22 20:30:28,758 INFO     pid:6164 __main__:421:logMetrics E3 trn_all  1.1677 loss,  83.9% tp,  16.1% fn,    7716.1% fp
# 2023-10-22 20:30:28,759 INFO     pid:6164 __main__:187:main Epoch 4 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:30:28,781 WARNING  pid:6164 util:109:enumerateWithEstimate E4 Training ----/203, starting
# 2023-10-22 20:30:58,941 INFO     pid:6164 util:126:enumerateWithEstimate E4 Training   64/203, done at 2023-10-22 20:31:20, 0:00:30
# 2023-10-22 20:31:20,929 WARNING  pid:6164 util:139:enumerateWithEstimate E4 Training ----/203, done at 2023-10-22 20:31:20
# 2023-10-22 20:31:20,929 INFO     pid:6164 __main__:381:logMetrics E4 SegmentationTrainingApp
# 2023-10-22 20:31:20,929 INFO     pid:6164 __main__:411:logMetrics E4 trn      1.1689 loss, 0.0114 precision, 0.8427 recall, 0.0224 f1 score
# 2023-10-22 20:31:20,929 INFO     pid:6164 __main__:421:logMetrics E4 trn_all  1.1689 loss,  84.3% tp,  15.7% fn,    7338.1% fp
# 2023-10-22 20:31:20,941 INFO     pid:6164 __main__:187:main Epoch 5 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:31:20,968 WARNING  pid:6164 util:109:enumerateWithEstimate E5 Training ----/203, starting
# 2023-10-22 20:31:42,738 INFO     pid:6164 util:126:enumerateWithEstimate E5 Training   64/203, done at 2023-10-22 20:32:04, 0:00:30
# 2023-10-22 20:32:04,712 WARNING  pid:6164 util:139:enumerateWithEstimate E5 Training ----/203, done at 2023-10-22 20:32:04
# 2023-10-22 20:32:04,712 INFO     pid:6164 __main__:381:logMetrics E5 SegmentationTrainingApp
# 2023-10-22 20:32:04,712 INFO     pid:6164 __main__:411:logMetrics E5 trn      1.1674 loss, 0.0127 precision, 0.8463 recall, 0.0249 f1 score
# 2023-10-22 20:32:04,712 INFO     pid:6164 __main__:421:logMetrics E5 trn_all  1.1674 loss,  84.6% tp,  15.4% fn,    6603.9% fp
# 2023-10-22 20:32:04,718 WARNING  pid:6164 util:109:enumerateWithEstimate E5 Validation  ----/17, starting
# 2023-10-22 20:32:27,626 INFO     pid:6164 util:126:enumerateWithEstimate E5 Validation    16/17, done at 2023-10-22 20:32:27, 0:00:02
# 2023-10-22 20:32:28,482 WARNING  pid:6164 util:139:enumerateWithEstimate E5 Validation  ----/17, done at 2023-10-22 20:32:28
# 2023-10-22 20:32:28,482 INFO     pid:6164 __main__:381:logMetrics E5 SegmentationTrainingApp
# 2023-10-22 20:32:28,482 INFO     pid:6164 __main__:411:logMetrics E5 val      1.1225 loss, 0.0039 precision, 0.9359 recall, 0.0078 f1 score
# 2023-10-22 20:32:28,482 INFO     pid:6164 __main__:421:logMetrics E5 val_all  1.1225 loss,  93.6% tp,   6.4% fn,   23764.3% fp
# 2023-10-22 20:32:28,509 INFO     pid:6164 __main__:474:saveModel Saved model params to models\udet\seg_2023-10-22_20.26.06_final-cls.8110.state
# 2023-10-22 20:32:28,516 INFO     pid:6164 __main__:486:saveModel SHA1: 721b9ac48c8b11d0d88080535c6416e208b82297
# 2023-10-22 20:33:47,908 INFO     pid:6164 __main__:187:main Epoch 6 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:33:47,944 WARNING  pid:6164 util:109:enumerateWithEstimate E6 Training ----/203, starting
# 2023-10-22 20:34:09,679 INFO     pid:6164 util:126:enumerateWithEstimate E6 Training   64/203, done at 2023-10-22 20:34:31, 0:00:30
# 2023-10-22 20:34:31,666 WARNING  pid:6164 util:139:enumerateWithEstimate E6 Training ----/203, done at 2023-10-22 20:34:31
# 2023-10-22 20:34:31,666 INFO     pid:6164 __main__:381:logMetrics E6 SegmentationTrainingApp
# 2023-10-22 20:34:31,666 INFO     pid:6164 __main__:411:logMetrics E6 trn      1.1576 loss, 0.0142 precision, 0.8505 recall, 0.0280 f1 score
# 2023-10-22 20:34:31,674 INFO     pid:6164 __main__:421:logMetrics E6 trn_all  1.1576 loss,  85.1% tp,  14.9% fn,    5899.7% fp
# 2023-10-22 20:34:31,675 INFO     pid:6164 __main__:187:main Epoch 7 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:34:31,701 WARNING  pid:6164 util:109:enumerateWithEstimate E7 Training ----/203, starting
# 2023-10-22 20:34:53,603 INFO     pid:6164 util:126:enumerateWithEstimate E7 Training   64/203, done at 2023-10-22 20:35:14, 0:00:30
# 2023-10-22 20:35:15,590 WARNING  pid:6164 util:139:enumerateWithEstimate E7 Training ----/203, done at 2023-10-22 20:35:15
# 2023-10-22 20:35:15,590 INFO     pid:6164 __main__:381:logMetrics E7 SegmentationTrainingApp
# 2023-10-22 20:35:15,590 INFO     pid:6164 __main__:411:logMetrics E7 trn      1.1475 loss, 0.0141 precision, 0.8547 recall, 0.0277 f1 score
# 2023-10-22 20:35:15,597 INFO     pid:6164 __main__:421:logMetrics E7 trn_all  1.1475 loss,  85.5% tp,  14.5% fn,    5982.6% fp
# 2023-10-22 20:35:15,597 INFO     pid:6164 __main__:187:main Epoch 8 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:35:15,627 WARNING  pid:6164 util:109:enumerateWithEstimate E8 Training ----/203, starting
# 2023-10-22 20:35:45,028 INFO     pid:6164 util:126:enumerateWithEstimate E8 Training   64/203, done at 2023-10-22 20:36:06, 0:00:30
# 2023-10-22 20:36:07,008 WARNING  pid:6164 util:139:enumerateWithEstimate E8 Training ----/203, done at 2023-10-22 20:36:07
# 2023-10-22 20:36:07,023 INFO     pid:6164 __main__:381:logMetrics E8 SegmentationTrainingApp
# 2023-10-22 20:36:07,025 INFO     pid:6164 __main__:411:logMetrics E8 trn      1.1519 loss, 0.0152 precision, 0.8588 recall, 0.0299 f1 score
# 2023-10-22 20:36:07,025 INFO     pid:6164 __main__:421:logMetrics E8 trn_all  1.1519 loss,  85.9% tp,  14.1% fn,    5564.2% fp
# 2023-10-22 20:36:07,027 INFO     pid:6164 __main__:187:main Epoch 9 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:36:07,057 WARNING  pid:6164 util:109:enumerateWithEstimate E9 Training ----/203, starting
# 2023-10-22 20:36:29,210 INFO     pid:6164 util:126:enumerateWithEstimate E9 Training   64/203, done at 2023-10-22 20:36:50, 0:00:30
# 2023-10-22 20:36:51,209 WARNING  pid:6164 util:139:enumerateWithEstimate E9 Training ----/203, done at 2023-10-22 20:36:51
# 2023-10-22 20:36:51,209 INFO     pid:6164 __main__:381:logMetrics E9 SegmentationTrainingApp
# 2023-10-22 20:36:51,209 INFO     pid:6164 __main__:411:logMetrics E9 trn      1.1459 loss, 0.0174 precision, 0.8607 recall, 0.0340 f1 score
# 2023-10-22 20:36:51,209 INFO     pid:6164 __main__:421:logMetrics E9 trn_all  1.1459 loss,  86.1% tp,  13.9% fn,    4874.2% fp
# 2023-10-22 20:36:51,226 INFO     pid:6164 __main__:187:main Epoch 10 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:36:51,251 WARNING  pid:6164 util:109:enumerateWithEstimate E10 Training ----/203, starting
# 2023-10-22 20:37:13,022 INFO     pid:6164 util:126:enumerateWithEstimate E10 Training   64/203, done at 2023-10-22 20:37:34, 0:00:30
# 2023-10-22 20:37:34,994 WARNING  pid:6164 util:139:enumerateWithEstimate E10 Training ----/203, done at 2023-10-22 20:37:34
# 2023-10-22 20:37:34,994 INFO     pid:6164 __main__:381:logMetrics E10 SegmentationTrainingApp
# 2023-10-22 20:37:34,994 INFO     pid:6164 __main__:411:logMetrics E10 trn      1.1331 loss, 0.0181 precision, 0.8685 recall, 0.0355 f1 score
# 2023-10-22 20:37:34,994 INFO     pid:6164 __main__:421:logMetrics E10 trn_all  1.1331 loss,  86.8% tp,  13.2% fn,    4711.7% fp
# 2023-10-22 20:37:35,005 WARNING  pid:6164 util:109:enumerateWithEstimate E10 Validation  ----/17, starting
# 2023-10-22 20:37:57,806 INFO     pid:6164 util:126:enumerateWithEstimate E10 Validation    16/17, done at 2023-10-22 20:37:57, 0:00:03
# 2023-10-22 20:37:58,671 WARNING  pid:6164 util:139:enumerateWithEstimate E10 Validation  ----/17, done at 2023-10-22 20:37:58
# 2023-10-22 20:37:58,671 INFO     pid:6164 __main__:381:logMetrics E10 SegmentationTrainingApp
# 2023-10-22 20:37:58,671 INFO     pid:6164 __main__:411:logMetrics E10 val      1.0700 loss, 0.0190 precision, 0.7694 recall, 0.0371 f1 score
# 2023-10-22 20:37:58,681 INFO     pid:6164 __main__:421:logMetrics E10 val_all  1.0700 loss,  76.9% tp,  23.1% fn,    3967.9% fp
# 2023-10-22 20:37:58,704 INFO     pid:6164 __main__:474:saveModel Saved model params to models\udet\seg_2023-10-22_20.26.06_final-cls.16220.state
# 2023-10-22 20:37:58,713 INFO     pid:6164 __main__:486:saveModel SHA1: 1d5469c84916e4c40862adab0f6abcf7eb761794
# 2023-10-22 20:39:19,305 INFO     pid:6164 __main__:187:main Epoch 11 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:39:19,335 WARNING  pid:6164 util:109:enumerateWithEstimate E11 Training ----/203, starting
# 2023-10-22 20:39:41,227 INFO     pid:6164 util:126:enumerateWithEstimate E11 Training   64/203, done at 2023-10-22 20:40:02, 0:00:29
# 2023-10-22 20:40:03,213 WARNING  pid:6164 util:139:enumerateWithEstimate E11 Training ----/203, done at 2023-10-22 20:40:03
# 2023-10-22 20:40:03,213 INFO     pid:6164 __main__:381:logMetrics E11 SegmentationTrainingApp
# 2023-10-22 20:40:03,220 INFO     pid:6164 __main__:411:logMetrics E11 trn      1.1359 loss, 0.0182 precision, 0.8723 recall, 0.0356 f1 score
# 2023-10-22 20:40:03,220 INFO     pid:6164 __main__:421:logMetrics E11 trn_all  1.1359 loss,  87.2% tp,  12.8% fn,    4713.7% fp
# 2023-10-22 20:40:03,221 INFO     pid:6164 __main__:187:main Epoch 12 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:40:03,246 WARNING  pid:6164 util:109:enumerateWithEstimate E12 Training ----/203, starting
# 2023-10-22 20:40:33,903 INFO     pid:6164 util:126:enumerateWithEstimate E12 Training   64/203, done at 2023-10-22 20:40:55, 0:00:30
# 2023-10-22 20:40:55,910 WARNING  pid:6164 util:139:enumerateWithEstimate E12 Training ----/203, done at 2023-10-22 20:40:55
# 2023-10-22 20:40:55,910 INFO     pid:6164 __main__:381:logMetrics E12 SegmentationTrainingApp
# 2023-10-22 20:40:55,917 INFO     pid:6164 __main__:411:logMetrics E12 trn      1.1451 loss, 0.0175 precision, 0.8676 recall, 0.0343 f1 score
# 2023-10-22 20:40:55,919 INFO     pid:6164 __main__:421:logMetrics E12 trn_all  1.1451 loss,  86.8% tp,  13.2% fn,    4878.1% fp
# 2023-10-22 20:40:55,921 INFO     pid:6164 __main__:187:main Epoch 13 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:40:55,946 WARNING  pid:6164 util:109:enumerateWithEstimate E13 Training ----/203, starting
# 2023-10-22 20:41:17,733 INFO     pid:6164 util:126:enumerateWithEstimate E13 Training   64/203, done at 2023-10-22 20:41:39, 0:00:30
# 2023-10-22 20:41:39,749 WARNING  pid:6164 util:139:enumerateWithEstimate E13 Training ----/203, done at 2023-10-22 20:41:39
# 2023-10-22 20:41:39,749 INFO     pid:6164 __main__:381:logMetrics E13 SegmentationTrainingApp
# 2023-10-22 20:41:39,749 INFO     pid:6164 __main__:411:logMetrics E13 trn      1.1252 loss, 0.0200 precision, 0.8689 recall, 0.0391 f1 score
# 2023-10-22 20:41:39,753 INFO     pid:6164 __main__:421:logMetrics E13 trn_all  1.1252 loss,  86.9% tp,  13.1% fn,    4258.4% fp
# 2023-10-22 20:41:39,755 INFO     pid:6164 __main__:187:main Epoch 14 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:41:39,785 WARNING  pid:6164 util:109:enumerateWithEstimate E14 Training ----/203, starting
# 2023-10-22 20:42:01,671 INFO     pid:6164 util:126:enumerateWithEstimate E14 Training   64/203, done at 2023-10-22 20:42:23, 0:00:30
# 2023-10-22 20:42:23,638 WARNING  pid:6164 util:139:enumerateWithEstimate E14 Training ----/203, done at 2023-10-22 20:42:23
# 2023-10-22 20:42:23,638 INFO     pid:6164 __main__:381:logMetrics E14 SegmentationTrainingApp
# 2023-10-22 20:42:23,653 INFO     pid:6164 __main__:411:logMetrics E14 trn      1.1360 loss, 0.0209 precision, 0.8781 recall, 0.0409 f1 score
# 2023-10-22 20:42:23,654 INFO     pid:6164 __main__:421:logMetrics E14 trn_all  1.1360 loss,  87.8% tp,  12.2% fn,    4104.7% fp
# 2023-10-22 20:42:23,655 INFO     pid:6164 __main__:187:main Epoch 15 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:42:23,679 WARNING  pid:6164 util:109:enumerateWithEstimate E15 Training ----/203, starting
# 2023-10-22 20:42:45,655 INFO     pid:6164 util:126:enumerateWithEstimate E15 Training   64/203, done at 2023-10-22 20:43:07, 0:00:30
# 2023-10-22 20:43:07,030 WARNING  pid:6164 util:139:enumerateWithEstimate E15 Training ----/203, done at 2023-10-22 20:43:07
# 2023-10-22 20:43:07,030 INFO     pid:6164 __main__:381:logMetrics E15 SegmentationTrainingApp
# 2023-10-22 20:43:07,030 INFO     pid:6164 __main__:411:logMetrics E15 trn      1.1260 loss, 0.0212 precision, 0.8831 recall, 0.0414 f1 score
# 2023-10-22 20:43:07,030 INFO     pid:6164 __main__:421:logMetrics E15 trn_all  1.1260 loss,  88.3% tp,  11.7% fn,    4075.5% fp
# 2023-10-22 20:43:07,040 WARNING  pid:6164 util:109:enumerateWithEstimate E15 Validation  ----/17, starting
# 2023-10-22 20:43:30,042 INFO     pid:6164 util:126:enumerateWithEstimate E15 Validation    16/17, done at 2023-10-22 20:43:30, 0:00:03
# 2023-10-22 20:43:30,954 WARNING  pid:6164 util:139:enumerateWithEstimate E15 Validation  ----/17, done at 2023-10-22 20:43:30
# 2023-10-22 20:43:30,954 INFO     pid:6164 __main__:381:logMetrics E15 SegmentationTrainingApp
# 2023-10-22 20:43:30,954 INFO     pid:6164 __main__:411:logMetrics E15 val      1.0785 loss, 0.0180 precision, 0.7463 recall, 0.0352 f1 score
# 2023-10-22 20:43:30,967 INFO     pid:6164 __main__:421:logMetrics E15 val_all  1.0785 loss,  74.6% tp,  25.4% fn,    4069.4% fp
# 2023-10-22 20:43:30,990 INFO     pid:6164 __main__:474:saveModel Saved model params to models\udet\seg_2023-10-22_20.26.06_final-cls.24330.state
# 2023-10-22 20:43:31,004 INFO     pid:6164 __main__:486:saveModel SHA1: 8a1d22155a5e536d608d1d3dfad97203baefade2
# 2023-10-22 20:44:55,123 INFO     pid:6164 __main__:187:main Epoch 16 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:44:55,148 WARNING  pid:6164 util:109:enumerateWithEstimate E16 Training ----/203, starting
# 2023-10-22 20:45:23,631 INFO     pid:6164 util:126:enumerateWithEstimate E16 Training   64/203, done at 2023-10-22 20:45:44, 0:00:30
# 2023-10-22 20:45:45,685 WARNING  pid:6164 util:139:enumerateWithEstimate E16 Training ----/203, done at 2023-10-22 20:45:45
# 2023-10-22 20:45:45,685 INFO     pid:6164 __main__:381:logMetrics E16 SegmentationTrainingApp
# 2023-10-22 20:45:45,685 INFO     pid:6164 __main__:411:logMetrics E16 trn      1.1400 loss, 0.0225 precision, 0.8746 recall, 0.0438 f1 score
# 2023-10-22 20:45:45,700 INFO     pid:6164 __main__:421:logMetrics E16 trn_all  1.1400 loss,  87.5% tp,  12.5% fn,    3803.8% fp
# 2023-10-22 20:45:45,701 INFO     pid:6164 __main__:187:main Epoch 17 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:45:45,728 WARNING  pid:6164 util:109:enumerateWithEstimate E17 Training ----/203, starting
# 2023-10-22 20:46:07,605 INFO     pid:6164 util:126:enumerateWithEstimate E17 Training   64/203, done at 2023-10-22 20:46:28, 0:00:30
# 2023-10-22 20:46:29,662 WARNING  pid:6164 util:139:enumerateWithEstimate E17 Training ----/203, done at 2023-10-22 20:46:29
# 2023-10-22 20:46:29,666 INFO     pid:6164 __main__:381:logMetrics E17 SegmentationTrainingApp
# 2023-10-22 20:46:29,667 INFO     pid:6164 __main__:411:logMetrics E17 trn      1.1240 loss, 0.0233 precision, 0.8830 recall, 0.0454 f1 score
# 2023-10-22 20:46:29,667 INFO     pid:6164 __main__:421:logMetrics E17 trn_all  1.1240 loss,  88.3% tp,  11.7% fn,    3700.7% fp
# 2023-10-22 20:46:29,669 INFO     pid:6164 __main__:187:main Epoch 18 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:46:29,695 WARNING  pid:6164 util:109:enumerateWithEstimate E18 Training ----/203, starting
# 2023-10-22 20:46:51,606 INFO     pid:6164 util:126:enumerateWithEstimate E18 Training   64/203, done at 2023-10-22 20:47:12, 0:00:30
# 2023-10-22 20:47:13,627 WARNING  pid:6164 util:139:enumerateWithEstimate E18 Training ----/203, done at 2023-10-22 20:47:13
# 2023-10-22 20:47:13,627 INFO     pid:6164 __main__:381:logMetrics E18 SegmentationTrainingApp
# 2023-10-22 20:47:13,627 INFO     pid:6164 __main__:411:logMetrics E18 trn      1.1215 loss, 0.0232 precision, 0.8797 recall, 0.0451 f1 score
# 2023-10-22 20:47:13,627 INFO     pid:6164 __main__:421:logMetrics E18 trn_all  1.1215 loss,  88.0% tp,  12.0% fn,    3710.9% fp
# 2023-10-22 20:47:13,642 INFO     pid:6164 __main__:187:main Epoch 19 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:47:13,667 WARNING  pid:6164 util:109:enumerateWithEstimate E19 Training ----/203, starting
# 2023-10-22 20:47:35,582 INFO     pid:6164 util:126:enumerateWithEstimate E19 Training   64/203, done at 2023-10-22 20:47:56, 0:00:30
# 2023-10-22 20:47:57,593 WARNING  pid:6164 util:139:enumerateWithEstimate E19 Training ----/203, done at 2023-10-22 20:47:57
# 2023-10-22 20:47:57,593 INFO     pid:6164 __main__:381:logMetrics E19 SegmentationTrainingApp
# 2023-10-22 20:47:57,609 INFO     pid:6164 __main__:411:logMetrics E19 trn      1.1333 loss, 0.0241 precision, 0.8833 recall, 0.0469 f1 score
# 2023-10-22 20:47:57,609 INFO     pid:6164 __main__:421:logMetrics E19 trn_all  1.1333 loss,  88.3% tp,  11.7% fn,    3582.2% fp
# 2023-10-22 20:47:57,610 INFO     pid:6164 __main__:187:main Epoch 20 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:47:57,636 WARNING  pid:6164 util:109:enumerateWithEstimate E20 Training ----/203, starting
# 2023-10-22 20:48:19,589 INFO     pid:6164 util:126:enumerateWithEstimate E20 Training   64/203, done at 2023-10-22 20:48:40, 0:00:30
# 2023-10-22 20:48:41,611 WARNING  pid:6164 util:139:enumerateWithEstimate E20 Training ----/203, done at 2023-10-22 20:48:41
# 2023-10-22 20:48:41,611 INFO     pid:6164 __main__:381:logMetrics E20 SegmentationTrainingApp
# 2023-10-22 20:48:41,611 INFO     pid:6164 __main__:411:logMetrics E20 trn      1.1183 loss, 0.0233 precision, 0.8966 recall, 0.0454 f1 score
# 2023-10-22 20:48:41,611 INFO     pid:6164 __main__:421:logMetrics E20 trn_all  1.1183 loss,  89.7% tp,  10.3% fn,    3761.9% fp
# 2023-10-22 20:48:41,617 WARNING  pid:6164 util:109:enumerateWithEstimate E20 Validation  ----/17, starting
# 2023-10-22 20:49:13,834 INFO     pid:6164 util:126:enumerateWithEstimate E20 Validation    16/17, done at 2023-10-22 20:49:13, 0:00:04
# 2023-10-22 20:49:14,710 WARNING  pid:6164 util:139:enumerateWithEstimate E20 Validation  ----/17, done at 2023-10-22 20:49:14
# 2023-10-22 20:49:14,727 INFO     pid:6164 __main__:381:logMetrics E20 SegmentationTrainingApp
# 2023-10-22 20:49:14,728 INFO     pid:6164 __main__:411:logMetrics E20 val      1.0849 loss, 0.0258 precision, 0.7042 recall, 0.0498 f1 score
# 2023-10-22 20:49:14,729 INFO     pid:6164 __main__:421:logMetrics E20 val_all  1.0849 loss,  70.4% tp,  29.6% fn,    2655.5% fp
# 2023-10-22 20:49:14,747 INFO     pid:6164 __main__:474:saveModel Saved model params to models\udet\seg_2023-10-22_20.26.06_final-cls.32440.state
# 2023-10-22 20:49:14,755 INFO     pid:6164 __main__:486:saveModel SHA1: d9eb18d81513e4048e339e1378ff2e2752a67e50
# 2023-10-22 20:50:09,777 INFO     pid:6164 __main__:187:main Epoch 21 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:50:09,810 WARNING  pid:6164 util:109:enumerateWithEstimate E21 Training ----/203, starting
# 2023-10-22 20:50:31,727 INFO     pid:6164 util:126:enumerateWithEstimate E21 Training   64/203, done at 2023-10-22 20:50:53, 0:00:30
# 2023-10-22 20:50:53,700 WARNING  pid:6164 util:139:enumerateWithEstimate E21 Training ----/203, done at 2023-10-22 20:50:53
# 2023-10-22 20:50:53,700 INFO     pid:6164 __main__:381:logMetrics E21 SegmentationTrainingApp
# 2023-10-22 20:50:53,709 INFO     pid:6164 __main__:411:logMetrics E21 trn      1.1224 loss, 0.0252 precision, 0.8931 recall, 0.0491 f1 score
# 2023-10-22 20:50:53,709 INFO     pid:6164 __main__:421:logMetrics E21 trn_all  1.1224 loss,  89.3% tp,  10.7% fn,    3451.8% fp
# 2023-10-22 20:50:53,711 INFO     pid:6164 __main__:187:main Epoch 22 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:50:53,733 WARNING  pid:6164 util:109:enumerateWithEstimate E22 Training ----/203, starting
# 2023-10-22 20:51:15,536 INFO     pid:6164 util:126:enumerateWithEstimate E22 Training   64/203, done at 2023-10-22 20:51:36, 0:00:30
# 2023-10-22 20:51:37,584 WARNING  pid:6164 util:139:enumerateWithEstimate E22 Training ----/203, done at 2023-10-22 20:51:37
# 2023-10-22 20:51:37,599 INFO     pid:6164 __main__:381:logMetrics E22 SegmentationTrainingApp
# 2023-10-22 20:51:37,600 INFO     pid:6164 __main__:411:logMetrics E22 trn      1.1103 loss, 0.0272 precision, 0.8987 recall, 0.0528 f1 score
# 2023-10-22 20:51:37,601 INFO     pid:6164 __main__:421:logMetrics E22 trn_all  1.1103 loss,  89.9% tp,  10.1% fn,    3214.4% fp
# 2023-10-22 20:51:37,603 INFO     pid:6164 __main__:187:main Epoch 23 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:51:37,633 WARNING  pid:6164 util:109:enumerateWithEstimate E23 Training ----/203, starting
# 2023-10-22 20:51:59,458 INFO     pid:6164 util:126:enumerateWithEstimate E23 Training   64/203, done at 2023-10-22 20:52:20, 0:00:30
# 2023-10-22 20:52:21,486 WARNING  pid:6164 util:139:enumerateWithEstimate E23 Training ----/203, done at 2023-10-22 20:52:21
# 2023-10-22 20:52:21,486 INFO     pid:6164 __main__:381:logMetrics E23 SegmentationTrainingApp
# 2023-10-22 20:52:21,486 INFO     pid:6164 __main__:411:logMetrics E23 trn      1.1142 loss, 0.0255 precision, 0.8946 recall, 0.0496 f1 score
# 2023-10-22 20:52:21,496 INFO     pid:6164 __main__:421:logMetrics E23 trn_all  1.1142 loss,  89.5% tp,  10.5% fn,    3420.6% fp
# 2023-10-22 20:52:21,496 INFO     pid:6164 __main__:187:main Epoch 24 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:52:21,521 WARNING  pid:6164 util:109:enumerateWithEstimate E24 Training ----/203, starting
# 2023-10-22 20:52:43,317 INFO     pid:6164 util:126:enumerateWithEstimate E24 Training   64/203, done at 2023-10-22 20:53:04, 0:00:30
# 2023-10-22 20:53:05,285 WARNING  pid:6164 util:139:enumerateWithEstimate E24 Training ----/203, done at 2023-10-22 20:53:05
# 2023-10-22 20:53:05,285 INFO     pid:6164 __main__:381:logMetrics E24 SegmentationTrainingApp
# 2023-10-22 20:53:05,285 INFO     pid:6164 __main__:411:logMetrics E24 trn      1.1160 loss, 0.0264 precision, 0.8910 recall, 0.0514 f1 score
# 2023-10-22 20:53:05,295 INFO     pid:6164 __main__:421:logMetrics E24 trn_all  1.1160 loss,  89.1% tp,  10.9% fn,    3280.5% fp
# 2023-10-22 20:53:05,296 INFO     pid:6164 __main__:187:main Epoch 25 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:53:05,322 WARNING  pid:6164 util:109:enumerateWithEstimate E25 Training ----/203, starting
# 2023-10-22 20:53:27,054 INFO     pid:6164 util:126:enumerateWithEstimate E25 Training   64/203, done at 2023-10-22 20:53:48, 0:00:30
# 2023-10-22 20:53:49,037 WARNING  pid:6164 util:139:enumerateWithEstimate E25 Training ----/203, done at 2023-10-22 20:53:49
# 2023-10-22 20:53:49,037 INFO     pid:6164 __main__:381:logMetrics E25 SegmentationTrainingApp
# 2023-10-22 20:53:49,037 INFO     pid:6164 __main__:411:logMetrics E25 trn      1.1065 loss, 0.0284 precision, 0.8982 recall, 0.0551 f1 score
# 2023-10-22 20:53:49,037 INFO     pid:6164 __main__:421:logMetrics E25 trn_all  1.1065 loss,  89.8% tp,  10.2% fn,    3069.1% fp
# 2023-10-22 20:53:49,048 WARNING  pid:6164 util:109:enumerateWithEstimate E25 Validation  ----/17, starting
# 2023-10-22 20:54:19,272 INFO     pid:6164 util:126:enumerateWithEstimate E25 Validation    16/17, done at 2023-10-22 20:54:19, 0:00:02
# 2023-10-22 20:54:20,212 WARNING  pid:6164 util:139:enumerateWithEstimate E25 Validation  ----/17, done at 2023-10-22 20:54:20
# 2023-10-22 20:54:20,212 INFO     pid:6164 __main__:381:logMetrics E25 SegmentationTrainingApp
# 2023-10-22 20:54:20,212 INFO     pid:6164 __main__:411:logMetrics E25 val      1.1411 loss, 0.0048 precision, 0.7483 recall, 0.0095 f1 score
# 2023-10-22 20:54:20,212 INFO     pid:6164 __main__:421:logMetrics E25 val_all  1.1411 loss,  74.8% tp,  25.2% fn,   15602.7% fp
# 2023-10-22 20:54:20,239 INFO     pid:6164 __main__:474:saveModel Saved model params to models\udet\seg_2023-10-22_20.26.06_final-cls.40550.state
# 2023-10-22 20:54:20,247 INFO     pid:6164 __main__:486:saveModel SHA1: 58a320f248e18fbc368f897f8a37f5262e9f5e2d
# 2023-10-22 20:55:45,307 INFO     pid:6164 __main__:187:main Epoch 26 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:55:45,338 WARNING  pid:6164 util:109:enumerateWithEstimate E26 Training ----/203, starting
# 2023-10-22 20:56:07,233 INFO     pid:6164 util:126:enumerateWithEstimate E26 Training   64/203, done at 2023-10-22 20:56:28, 0:00:30
# 2023-10-22 20:56:29,205 WARNING  pid:6164 util:139:enumerateWithEstimate E26 Training ----/203, done at 2023-10-22 20:56:29
# 2023-10-22 20:56:29,206 INFO     pid:6164 __main__:381:logMetrics E26 SegmentationTrainingApp
# 2023-10-22 20:56:29,207 INFO     pid:6164 __main__:411:logMetrics E26 trn      1.1264 loss, 0.0263 precision, 0.8959 recall, 0.0512 f1 score
# 2023-10-22 20:56:29,207 INFO     pid:6164 __main__:421:logMetrics E26 trn_all  1.1264 loss,  89.6% tp,  10.4% fn,    3312.8% fp
# 2023-10-22 20:56:29,209 INFO     pid:6164 __main__:187:main Epoch 27 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:56:29,233 WARNING  pid:6164 util:109:enumerateWithEstimate E27 Training ----/203, starting
# 2023-10-22 20:56:51,022 INFO     pid:6164 util:126:enumerateWithEstimate E27 Training   64/203, done at 2023-10-22 20:57:12, 0:00:30
# 2023-10-22 20:57:13,171 WARNING  pid:6164 util:139:enumerateWithEstimate E27 Training ----/203, done at 2023-10-22 20:57:13
# 2023-10-22 20:57:13,173 INFO     pid:6164 __main__:381:logMetrics E27 SegmentationTrainingApp
# 2023-10-22 20:57:13,174 INFO     pid:6164 __main__:411:logMetrics E27 trn      1.1112 loss, 0.0271 precision, 0.8951 recall, 0.0527 f1 score
# 2023-10-22 20:57:13,174 INFO     pid:6164 __main__:421:logMetrics E27 trn_all  1.1112 loss,  89.5% tp,  10.5% fn,    3208.6% fp
# 2023-10-22 20:57:13,176 INFO     pid:6164 __main__:187:main Epoch 28 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:57:13,206 WARNING  pid:6164 util:109:enumerateWithEstimate E28 Training ----/203, starting
# 2023-10-22 20:57:34,974 INFO     pid:6164 util:126:enumerateWithEstimate E28 Training   64/203, done at 2023-10-22 20:57:56, 0:00:30
# 2023-10-22 20:57:56,943 WARNING  pid:6164 util:139:enumerateWithEstimate E28 Training ----/203, done at 2023-10-22 20:57:56
# 2023-10-22 20:57:56,944 INFO     pid:6164 __main__:381:logMetrics E28 SegmentationTrainingApp
# 2023-10-22 20:57:56,944 INFO     pid:6164 __main__:411:logMetrics E28 trn      1.1000 loss, 0.0301 precision, 0.9016 recall, 0.0582 f1 score
# 2023-10-22 20:57:56,945 INFO     pid:6164 __main__:421:logMetrics E28 trn_all  1.1000 loss,  90.2% tp,   9.8% fn,    2906.3% fp
# 2023-10-22 20:57:56,946 INFO     pid:6164 __main__:187:main Epoch 29 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:57:56,966 WARNING  pid:6164 util:109:enumerateWithEstimate E29 Training ----/203, starting
# 2023-10-22 20:58:18,805 INFO     pid:6164 util:126:enumerateWithEstimate E29 Training   64/203, done at 2023-10-22 20:58:40, 0:00:30
# 2023-10-22 20:58:40,893 WARNING  pid:6164 util:139:enumerateWithEstimate E29 Training ----/203, done at 2023-10-22 20:58:40
# 2023-10-22 20:58:40,895 INFO     pid:6164 __main__:381:logMetrics E29 SegmentationTrainingApp
# 2023-10-22 20:58:40,896 INFO     pid:6164 __main__:411:logMetrics E29 trn      1.1161 loss, 0.0299 precision, 0.9012 recall, 0.0578 f1 score
# 2023-10-22 20:58:40,896 INFO     pid:6164 __main__:421:logMetrics E29 trn_all  1.1161 loss,  90.1% tp,   9.9% fn,    2926.2% fp
# 2023-10-22 20:58:40,898 INFO     pid:6164 __main__:187:main Epoch 30 of 400, 203/17 batches of size 8*1
# 2023-10-22 20:58:40,922 WARNING  pid:6164 util:109:enumerateWithEstimate E30 Training ----/203, starting
# 2023-10-22 20:59:10,779 INFO     pid:6164 util:126:enumerateWithEstimate E30 Training   64/203, done at 2023-10-22 20:59:32, 0:00:30
# 2023-10-22 20:59:32,745 WARNING  pid:6164 util:139:enumerateWithEstimate E30 Training ----/203, done at 2023-10-22 20:59:32
# 2023-10-22 20:59:32,746 INFO     pid:6164 __main__:381:logMetrics E30 SegmentationTrainingApp
# 2023-10-22 20:59:32,747 INFO     pid:6164 __main__:411:logMetrics E30 trn      1.1099 loss, 0.0310 precision, 0.9036 recall, 0.0599 f1 score
# 2023-10-22 20:59:32,747 INFO     pid:6164 __main__:421:logMetrics E30 trn_all  1.1099 loss,  90.4% tp,   9.6% fn,    2828.9% fp
# 2023-10-22 20:59:32,748 WARNING  pid:6164 util:109:enumerateWithEstimate E30 Validation  ----/17, starting
# 2023-10-22 20:59:55,636 INFO     pid:6164 util:126:enumerateWithEstimate E30 Validation    16/17, done at 2023-10-22 20:59:55, 0:00:03
# 2023-10-22 20:59:56,526 WARNING  pid:6164 util:139:enumerateWithEstimate E30 Validation  ----/17, done at 2023-10-22 20:59:56
# 2023-10-22 20:59:56,526 INFO     pid:6164 __main__:381:logMetrics E30 SegmentationTrainingApp
# 2023-10-22 20:59:56,527 INFO     pid:6164 __main__:411:logMetrics E30 val      1.0756 loss, 0.0268 precision, 0.7311 recall, 0.0516 f1 score
# 2023-10-22 20:59:56,527 INFO     pid:6164 __main__:421:logMetrics E30 val_all  1.0756 loss,  73.1% tp,  26.9% fn,    2658.9% fp
# 2023-10-22 20:59:56,543 INFO     pid:6164 __main__:474:saveModel Saved model params to models\udet\seg_2023-10-22_20.26.06_final-cls.48660.state
# 2023-10-22 20:59:56,552 INFO     pid:6164 __main__:486:saveModel SHA1: f302ca6815ada73f198e861fa2b0118e7ea11278
# 2023-10-22 21:01:11,681 INFO     pid:6164 __main__:187:main Epoch 31 of 400, 203/17 batches of size 8*1
# 2023-10-22 21:01:11,711 WARNING  pid:6164 util:109:enumerateWithEstimate E31 Training ----/203, starting
# 2023-10-22 21:01:33,724 INFO     pid:6164 util:126:enumerateWithEstimate E31 Training   64/203, done at 2023-10-22 21:01:55, 0:00:30
# 2023-10-22 21:01:55,699 WARNING  pid:6164 util:139:enumerateWithEstimate E31 Training ----/203, done at 2023-10-22 21:01:55
# 2023-10-22 21:01:55,701 INFO     pid:6164 __main__:381:logMetrics E31 SegmentationTrainingApp
# 2023-10-22 21:01:55,701 INFO     pid:6164 __main__:411:logMetrics E31 trn      1.1118 loss, 0.0320 precision, 0.9006 recall, 0.0617 f1 score
# 2023-10-22 21:01:55,702 INFO     pid:6164 __main__:421:logMetrics E31 trn_all  1.1118 loss,  90.1% tp,   9.9% fn,    2728.5% fp
# 2023-10-22 21:01:55,704 INFO     pid:6164 __main__:187:main Epoch 32 of 400, 203/17 batches of size 8*1
# 2023-10-22 21:01:55,729 WARNING  pid:6164 util:109:enumerateWithEstimate E32 Training ----/203, starting
# 2023-10-22 21:02:17,507 INFO     pid:6164 util:126:enumerateWithEstimate E32 Training   64/203, done at 2023-10-22 21:02:38, 0:00:30
# 2023-10-22 21:02:39,474 WARNING  pid:6164 util:139:enumerateWithEstimate E32 Training ----/203, done at 2023-10-22 21:02:39
# 2023-10-22 21:02:39,475 INFO     pid:6164 __main__:381:logMetrics E32 SegmentationTrainingApp
# 2023-10-22 21:02:39,476 INFO     pid:6164 __main__:411:logMetrics E32 trn      1.1139 loss, 0.0302 precision, 0.9033 recall, 0.0585 f1 score
# 2023-10-22 21:02:39,476 INFO     pid:6164 __main__:421:logMetrics E32 trn_all  1.1139 loss,  90.3% tp,   9.7% fn,    2898.5% fp
# 2023-10-22 21:02:39,478 INFO     pid:6164 __main__:187:main Epoch 33 of 400, 203/17 batches of size 8*1
# 2023-10-22 21:02:39,499 WARNING  pid:6164 util:109:enumerateWithEstimate E33 Training ----/203, starting
# 2023-10-22 21:03:01,303 INFO     pid:6164 util:126:enumerateWithEstimate E33 Training   64/203, done at 2023-10-22 21:03:22, 0:00:30
# 2023-10-22 21:03:23,304 WARNING  pid:6164 util:139:enumerateWithEstimate E33 Training ----/203, done at 2023-10-22 21:03:23
# 2023-10-22 21:03:23,305 INFO     pid:6164 __main__:381:logMetrics E33 SegmentationTrainingApp
# 2023-10-22 21:03:23,306 INFO     pid:6164 __main__:411:logMetrics E33 trn      1.1121 loss, 0.0327 precision, 0.8995 recall, 0.0631 f1 score
# 2023-10-22 21:03:23,306 INFO     pid:6164 __main__:421:logMetrics E33 trn_all  1.1121 loss,  90.0% tp,  10.0% fn,    2663.2% fp
# 2023-10-22 21:03:23,308 INFO     pid:6164 __main__:187:main Epoch 34 of 400, 203/17 batches of size 8*1
# 2023-10-22 21:03:23,330 WARNING  pid:6164 util:109:enumerateWithEstimate E34 Training ----/203, starting
# 2023-10-22 21:03:53,086 INFO     pid:6164 util:126:enumerateWithEstimate E34 Training   64/203, done at 2023-10-22 21:04:14, 0:00:30
# 2023-10-22 21:04:15,149 WARNING  pid:6164 util:139:enumerateWithEstimate E34 Training ----/203, done at 2023-10-22 21:04:15
# 2023-10-22 21:04:15,150 INFO     pid:6164 __main__:381:logMetrics E34 SegmentationTrainingApp
# 2023-10-22 21:04:15,151 INFO     pid:6164 __main__:411:logMetrics E34 trn      1.1045 loss, 0.0331 precision, 0.9059 recall, 0.0638 f1 score
# 2023-10-22 21:04:15,151 INFO     pid:6164 __main__:421:logMetrics E34 trn_all  1.1045 loss,  90.6% tp,   9.4% fn,    2649.1% fp
# 2023-10-22 21:04:15,152 INFO     pid:6164 __main__:187:main Epoch 35 of 400, 203/17 batches of size 8*1
# 2023-10-22 21:04:15,170 WARNING  pid:6164 util:109:enumerateWithEstimate E35 Training ----/203, starting
# 2023-10-22 21:04:37,076 INFO     pid:6164 util:126:enumerateWithEstimate E35 Training   64/203, done at 2023-10-22 21:04:58, 0:00:30
# 2023-10-22 21:04:59,050 WARNING  pid:6164 util:139:enumerateWithEstimate E35 Training ----/203, done at 2023-10-22 21:04:59
# 2023-10-22 21:04:59,051 INFO     pid:6164 __main__:381:logMetrics E35 SegmentationTrainingApp
# 2023-10-22 21:04:59,051 INFO     pid:6164 __main__:411:logMetrics E35 trn      1.1086 loss, 0.0323 precision, 0.9065 recall, 0.0624 f1 score
# 2023-10-22 21:04:59,052 INFO     pid:6164 __main__:421:logMetrics E35 trn_all  1.1086 loss,  90.6% tp,   9.4% fn,    2713.0% fp
# 2023-10-22 21:04:59,054 WARNING  pid:6164 util:109:enumerateWithEstimate E35 Validation  ----/17, starting
# 2023-10-22 21:05:21,786 INFO     pid:6164 util:126:enumerateWithEstimate E35 Validation    16/17, done at 2023-10-22 21:05:21, 0:00:03
# 2023-10-22 21:05:22,598 WARNING  pid:6164 util:139:enumerateWithEstimate E35 Validation  ----/17, done at 2023-10-22 21:05:22
# 2023-10-22 21:05:22,599 INFO     pid:6164 __main__:381:logMetrics E35 SegmentationTrainingApp
# 2023-10-22 21:05:22,599 INFO     pid:6164 __main__:411:logMetrics E35 val      1.0787 loss, 0.0258 precision, 0.7243 recall, 0.0499 f1 score
# 2023-10-22 21:05:22,599 INFO     pid:6164 __main__:421:logMetrics E35 val_all  1.0787 loss,  72.4% tp,  27.6% fn,    2731.2% fp
# 2023-10-22 21:05:22,611 INFO     pid:6164 __main__:474:saveModel Saved model params to models\udet\seg_2023-10-22_20.26.06_final-cls.56770.state
# 2023-10-22 21:05:22,619 INFO     pid:6164 __main__:486:saveModel SHA1: 5403d1d7919aef771a40a3251b123779865ce851
# 2023-10-22 21:06:37,301 INFO     pid:6164 __main__:187:main Epoch 36 of 400, 203/17 batches of size 8*1
# 2023-10-22 21:06:37,328 WARNING  pid:6164 util:109:enumerateWithEstimate E36 Training ----/203, starting
# 2023-10-22 21:06:59,151 INFO     pid:6164 util:126:enumerateWithEstimate E36 Training   64/203, done at 2023-10-22 21:07:20, 0:00:30
# 2023-10-22 21:07:21,144 WARNING  pid:6164 util:139:enumerateWithEstimate E36 Training ----/203, done at 2023-10-22 21:07:21
# 2023-10-22 21:07:21,145 INFO     pid:6164 __main__:381:logMetrics E36 SegmentationTrainingApp
# 2023-10-22 21:07:21,145 INFO     pid:6164 __main__:411:logMetrics E36 trn      1.1027 loss, 0.0337 precision, 0.9058 recall, 0.0651 f1 score
# 2023-10-22 21:07:21,146 INFO     pid:6164 __main__:421:logMetrics E36 trn_all  1.1027 loss,  90.6% tp,   9.4% fn,    2593.4% fp
# 2023-10-22 21:07:21,147 INFO     pid:6164 __main__:187:main Epoch 37 of 400, 203/17 batches of size 8*1
# 2023-10-22 21:07:21,170 WARNING  pid:6164 util:109:enumerateWithEstimate E37 Training ----/203, starting
# 2023-10-22 21:07:43,013 INFO     pid:6164 util:126:enumerateWithEstimate E37 Training   64/203, done at 2023-10-22 21:08:04, 0:00:30
# 2023-10-22 21:08:04,976 WARNING  pid:6164 util:139:enumerateWithEstimate E37 Training ----/203, done at 2023-10-22 21:08:04
# 2023-10-22 21:08:04,977 INFO     pid:6164 __main__:381:logMetrics E37 SegmentationTrainingApp
# 2023-10-22 21:08:04,978 INFO     pid:6164 __main__:411:logMetrics E37 trn      1.1164 loss, 0.0360 precision, 0.9101 recall, 0.0693 f1 score
# 2023-10-22 21:08:04,978 INFO     pid:6164 __main__:421:logMetrics E37 trn_all  1.1164 loss,  91.0% tp,   9.0% fn,    2436.3% fp
# 2023-10-22 21:08:04,980 INFO     pid:6164 __main__:187:main Epoch 38 of 400, 203/17 batches of size 8*1
# 2023-10-22 21:08:04,997 WARNING  pid:6164 util:109:enumerateWithEstimate E38 Training ----/203, starting
# 2023-10-22 21:08:35,766 INFO     pid:6164 util:126:enumerateWithEstimate E38 Training   64/203, done at 2023-10-22 21:08:57, 0:00:30
# 2023-10-22 21:08:57,751 WARNING  pid:6164 util:139:enumerateWithEstimate E38 Training ----/203, done at 2023-10-22 21:08:57
# 2023-10-22 21:08:57,752 INFO     pid:6164 __main__:381:logMetrics E38 SegmentationTrainingApp
# 2023-10-22 21:08:57,753 INFO     pid:6164 __main__:411:logMetrics E38 trn      1.1023 loss, 0.0353 precision, 0.9106 recall, 0.0680 f1 score
# 2023-10-22 21:08:57,753 INFO     pid:6164 __main__:421:logMetrics E38 trn_all  1.1023 loss,  91.1% tp,   8.9% fn,    2485.3% fp
# 2023-10-22 21:08:57,755 INFO     pid:6164 __main__:187:main Epoch 39 of 400, 203/17 batches of size 8*1
# 2023-10-22 21:08:57,779 WARNING  pid:6164 util:109:enumerateWithEstimate E39 Training ----/203, starting
# 2023-10-22 21:09:19,537 INFO     pid:6164 util:126:enumerateWithEstimate E39 Training   64/203, done at 2023-10-22 21:09:40, 0:00:30
# 2023-10-22 21:09:41,532 WARNING  pid:6164 util:139:enumerateWithEstimate E39 Training ----/203, done at 2023-10-22 21:09:41
# 2023-10-22 21:09:41,533 INFO     pid:6164 __main__:381:logMetrics E39 SegmentationTrainingApp
# 2023-10-22 21:09:41,534 INFO     pid:6164 __main__:411:logMetrics E39 trn      1.1114 loss, 0.0373 precision, 0.9080 recall, 0.0716 f1 score
# 2023-10-22 21:09:41,534 INFO     pid:6164 __main__:421:logMetrics E39 trn_all  1.1114 loss,  90.8% tp,   9.2% fn,    2345.8% fp
# 2023-10-22 21:09:41,536 INFO     pid:6164 __main__:187:main Epoch 40 of 400, 203/17 batches of size 8*1
# 2023-10-22 21:09:41,556 WARNING  pid:6164 util:109:enumerateWithEstimate E40 Training ----/203, starting
# 2023-10-22 21:10:03,564 INFO     pid:6164 util:126:enumerateWithEstimate E40 Training   64/203, done at 2023-10-22 21:10:24, 0:00:30
# 2023-10-22 21:10:25,597 WARNING  pid:6164 util:139:enumerateWithEstimate E40 Training ----/203, done at 2023-10-22 21:10:25
# 2023-10-22 21:10:25,599 INFO     pid:6164 __main__:381:logMetrics E40 SegmentationTrainingApp
# 2023-10-22 21:10:25,600 INFO     pid:6164 __main__:411:logMetrics E40 trn      1.0939 loss, 0.0352 precision, 0.9094 recall, 0.0678 f1 score
# 2023-10-22 21:10:25,602 INFO     pid:6164 __main__:421:logMetrics E40 trn_all  1.0939 loss,  90.9% tp,   9.1% fn,    2490.8% fp
# 2023-10-22 21:10:25,604 WARNING  pid:6164 util:109:enumerateWithEstimate E40 Validation  ----/17, starting
# 2023-10-22 21:10:48,362 INFO     pid:6164 util:126:enumerateWithEstimate E40 Validation    16/17, done at 2023-10-22 21:10:48, 0:00:03
# 2023-10-22 21:10:49,312 WARNING  pid:6164 util:139:enumerateWithEstimate E40 Validation  ----/17, done at 2023-10-22 21:10:49
# 2023-10-22 21:10:49,313 INFO     pid:6164 __main__:381:logMetrics E40 SegmentationTrainingApp
# 2023-10-22 21:10:49,314 INFO     pid:6164 __main__:411:logMetrics E40 val      1.0836 loss, 0.0268 precision, 0.7068 recall, 0.0516 f1 score
# 2023-10-22 21:10:49,315 INFO     pid:6164 __main__:421:logMetrics E40 val_all  1.0836 loss,  70.7% tp,  29.3% fn,    2570.7% fp
# 2023-10-22 21:10:49,360 INFO     pid:6164 __main__:474:saveModel Saved model params to models\udet\seg_2023-10-22_20.26.06_final-cls.64880.state
# 2023-10-22 21:10:49,375 INFO     pid:6164 __main__:486:saveModel SHA1: 4cc74d7236913d07f29c56af5b61669f5af7a96d
# 2023-10-22 21:12:09,560 INFO     pid:6164 __main__:187:main Epoch 41 of 400, 203/17 batches of size 8*1
# 2023-10-22 21:12:09,585 WARNING  pid:6164 util:109:enumerateWithEstimate E41 Training ----/203, starting
# 2023-10-22 21:12:32,070 INFO     pid:6164 util:126:enumerateWithEstimate E41 Training   64/203, done at 2023-10-22 21:12:53, 0:00:29
# 2023-10-22 21:12:54,065 WARNING  pid:6164 util:139:enumerateWithEstimate E41 Training ----/203, done at 2023-10-22 21:12:54
# 2023-10-22 21:12:54,066 INFO     pid:6164 __main__:381:logMetrics E41 SegmentationTrainingApp
# 2023-10-22 21:12:54,066 INFO     pid:6164 __main__:411:logMetrics E41 trn      1.1078 loss, 0.0362 precision, 0.9094 recall, 0.0695 f1 score
# 2023-10-22 21:12:54,067 INFO     pid:6164 __main__:421:logMetrics E41 trn_all  1.1078 loss,  90.9% tp,   9.1% fn,    2424.3% fp
# 2023-10-22 21:12:54,069 INFO     pid:6164 __main__:187:main Epoch 42 of 400, 203/17 batches of size 8*1
# 2023-10-22 21:12:54,093 WARNING  pid:6164 util:109:enumerateWithEstimate E42 Training ----/203, starting
# 2023-10-22 21:13:25,033 INFO     pid:6164 util:126:enumerateWithEstimate E42 Training   64/203, done at 2023-10-22 21:13:46, 0:00:30
# 2023-10-22 21:13:47,051 WARNING  pid:6164 util:139:enumerateWithEstimate E42 Training ----/203, done at 2023-10-22 21:13:47
# 2023-10-22 21:13:47,052 INFO     pid:6164 __main__:381:logMetrics E42 SegmentationTrainingApp
# 2023-10-22 21:13:47,053 INFO     pid:6164 __main__:411:logMetrics E42 trn      1.1087 loss, 0.0365 precision, 0.9043 recall, 0.0703 f1 score
# 2023-10-22 21:13:47,053 INFO     pid:6164 __main__:421:logMetrics E42 trn_all  1.1087 loss,  90.4% tp,   9.6% fn,    2383.9% fp
# 2023-10-22 21:13:47,055 INFO     pid:6164 __main__:187:main Epoch 43 of 400, 203/17 batches of size 8*1
# 2023-10-22 21:13:47,081 WARNING  pid:6164 util:109:enumerateWithEstimate E43 Training ----/203, starting
# 2023-10-22 21:14:08,874 INFO     pid:6164 util:126:enumerateWithEstimate E43 Training   64/203, done at 2023-10-22 21:14:30, 0:00:30
# 2023-10-22 21:14:30,835 WARNING  pid:6164 util:139:enumerateWithEstimate E43 Training ----/203, done at 2023-10-22 21:14:30
# 2023-10-22 21:14:30,836 INFO     pid:6164 __main__:381:logMetrics E43 SegmentationTrainingApp
# 2023-10-22 21:14:30,837 INFO     pid:6164 __main__:411:logMetrics E43 trn      1.1061 loss, 0.0355 precision, 0.9085 recall, 0.0683 f1 score
# 2023-10-22 21:14:30,838 INFO     pid:6164 __main__:421:logMetrics E43 trn_all  1.1061 loss,  90.8% tp,   9.2% fn,    2469.0% fp
# 2023-10-22 21:14:30,839 INFO     pid:6164 __main__:187:main Epoch 44 of 400, 203/17 batches of size 8*1
# 2023-10-22 21:14:30,865 WARNING  pid:6164 util:109:enumerateWithEstimate E44 Training ----/203, starting
# 2023-10-22 21:14:52,816 INFO     pid:6164 util:126:enumerateWithEstimate E44 Training   64/203, done at 2023-10-22 21:15:14, 0:00:30
# 2023-10-22 21:15:14,539 WARNING  pid:6164 util:139:enumerateWithEstimate E44 Training ----/203, done at 2023-10-22 21:15:14
# 2023-10-22 21:15:14,540 INFO     pid:6164 __main__:381:logMetrics E44 SegmentationTrainingApp
# 2023-10-22 21:15:14,541 INFO     pid:6164 __main__:411:logMetrics E44 trn      1.1044 loss, 0.0374 precision, 0.9107 recall, 0.0718 f1 score
# 2023-10-22 21:15:14,541 INFO     pid:6164 __main__:421:logMetrics E44 trn_all  1.1044 loss,  91.1% tp,   8.9% fn,    2346.9% fp
# 2023-10-22 21:15:14,543 INFO     pid:6164 __main__:187:main Epoch 45 of 400, 203/17 batches of size 8*1
# 2023-10-22 21:15:14,567 WARNING  pid:6164 util:109:enumerateWithEstimate E45 Training ----/203, starting
# 2023-10-22 21:15:36,577 INFO     pid:6164 util:126:enumerateWithEstimate E45 Training   64/203, done at 2023-10-22 21:15:57, 0:00:30
# 2023-10-22 21:15:58,561 WARNING  pid:6164 util:139:enumerateWithEstimate E45 Training ----/203, done at 2023-10-22 21:15:58
# 2023-10-22 21:15:58,562 INFO     pid:6164 __main__:381:logMetrics E45 SegmentationTrainingApp
# 2023-10-22 21:15:58,562 INFO     pid:6164 __main__:411:logMetrics E45 trn      1.1119 loss, 0.0390 precision, 0.9098 recall, 0.0748 f1 score
# 2023-10-22 21:15:58,562 INFO     pid:6164 __main__:421:logMetrics E45 trn_all  1.1119 loss,  91.0% tp,   9.0% fn,    2240.3% fp
# 2023-10-22 21:15:58,565 WARNING  pid:6164 util:109:enumerateWithEstimate E45 Validation  ----/17, starting
# 2023-10-22 21:16:21,828 INFO     pid:6164 util:126:enumerateWithEstimate E45 Validation    16/17, done at 2023-10-22 21:16:21, 0:00:03
# 2023-10-22 21:16:22,679 WARNING  pid:6164 util:139:enumerateWithEstimate E45 Validation  ----/17, done at 2023-10-22 21:16:22
# 2023-10-22 21:16:22,679 INFO     pid:6164 __main__:381:logMetrics E45 SegmentationTrainingApp
# 2023-10-22 21:16:22,680 INFO     pid:6164 __main__:411:logMetrics E45 val      1.0920 loss, 0.0224 precision, 0.6894 recall, 0.0433 f1 score
# 2023-10-22 21:16:22,680 INFO     pid:6164 __main__:421:logMetrics E45 val_all  1.0920 loss,  68.9% tp,  31.1% fn,    3011.8% fp
# 2023-10-22 21:16:22,706 INFO     pid:6164 __main__:474:saveModel Saved model params to models\udet\seg_2023-10-22_20.26.06_final-cls.72990.state
# ...
# 2023-10-23 01:54:17,018 INFO     pid:6164 util:126:enumerateWithEstimate E306 Training   64/203, done at 2023-10-23 01:54:38, 0:00:30
# 2023-10-23 01:54:38,970 WARNING  pid:6164 util:139:enumerateWithEstimate E306 Training ----/203, done at 2023-10-23 01:54:38
# 2023-10-23 01:54:38,970 INFO     pid:6164 __main__:381:logMetrics E306 SegmentationTrainingApp
# 2023-10-23 01:54:38,970 INFO     pid:6164 __main__:411:logMetrics E306 trn      1.0544 loss, 0.0995 precision, 0.9928 recall, 0.1809 f1 score
# 2023-10-23 01:54:38,970 INFO     pid:6164 __main__:421:logMetrics E306 trn_all  1.0544 loss,  99.3% tp,   0.7% fn,     898.6% fp
# 2023-10-23 01:54:38,987 INFO     pid:6164 __main__:187:main Epoch 307 of 400, 203/17 batches of size 8*1
# 2023-10-23 01:54:39,010 WARNING  pid:6164 util:109:enumerateWithEstimate E307 Training ----/203, starting
# 2023-10-23 01:55:08,803 INFO     pid:6164 util:126:enumerateWithEstimate E307 Training   64/203, done at 2023-10-23 01:55:30, 0:00:30
# 2023-10-23 01:55:30,790 WARNING  pid:6164 util:139:enumerateWithEstimate E307 Training ----/203, done at 2023-10-23 01:55:30
# 2023-10-23 01:55:30,790 INFO     pid:6164 __main__:381:logMetrics E307 SegmentationTrainingApp
# 2023-10-23 01:55:30,790 INFO     pid:6164 __main__:411:logMetrics E307 trn      1.0573 loss, 0.1097 precision, 0.9934 recall, 0.1977 f1 score
# 2023-10-23 01:55:30,799 INFO     pid:6164 __main__:421:logMetrics E307 trn_all  1.0573 loss,  99.3% tp,   0.7% fn,     805.8% fp
# 2023-10-23 01:55:30,801 INFO     pid:6164 __main__:187:main Epoch 308 of 400, 203/17 batches of size 8*1
# 2023-10-23 01:55:30,825 WARNING  pid:6164 util:109:enumerateWithEstimate E308 Training ----/203, starting
# 2023-10-23 01:55:52,633 INFO     pid:6164 util:126:enumerateWithEstimate E308 Training   64/203, done at 2023-10-23 01:56:13, 0:00:30
# 2023-10-23 01:56:14,681 WARNING  pid:6164 util:139:enumerateWithEstimate E308 Training ----/203, done at 2023-10-23 01:56:14
# 2023-10-23 01:56:14,697 INFO     pid:6164 __main__:381:logMetrics E308 SegmentationTrainingApp
# 2023-10-23 01:56:14,697 INFO     pid:6164 __main__:411:logMetrics E308 trn      1.0615 loss, 0.0784 precision, 0.9892 recall, 0.1453 f1 score
# 2023-10-23 01:56:14,697 INFO     pid:6164 __main__:421:logMetrics E308 trn_all  1.0615 loss,  98.9% tp,   1.1% fn,    1162.5% fp
# 2023-10-23 01:56:14,701 INFO     pid:6164 __main__:187:main Epoch 309 of 400, 203/17 batches of size 8*1
# 2023-10-23 01:56:14,720 WARNING  pid:6164 util:109:enumerateWithEstimate E309 Training ----/203, starting
# 2023-10-23 01:56:36,817 INFO     pid:6164 util:126:enumerateWithEstimate E309 Training   64/203, done at 2023-10-23 01:56:58, 0:00:30
# 2023-10-23 01:56:58,150 WARNING  pid:6164 util:139:enumerateWithEstimate E309 Training ----/203, done at 2023-10-23 01:56:58
# 2023-10-23 01:56:58,150 INFO     pid:6164 __main__:381:logMetrics E309 SegmentationTrainingApp
# 2023-10-23 01:56:58,150 INFO     pid:6164 __main__:411:logMetrics E309 trn      1.0672 loss, 0.0772 precision, 0.9876 recall, 0.1432 f1 score
# 2023-10-23 01:56:58,150 INFO     pid:6164 __main__:421:logMetrics E309 trn_all  1.0672 loss,  98.8% tp,   1.2% fn,    1181.0% fp
# 2023-10-23 01:56:58,164 INFO     pid:6164 __main__:187:main Epoch 310 of 400, 203/17 batches of size 8*1
# 2023-10-23 01:56:58,189 WARNING  pid:6164 util:109:enumerateWithEstimate E310 Training ----/203, starting
# 2023-10-23 01:57:20,215 INFO     pid:6164 util:126:enumerateWithEstimate E310 Training   64/203, done at 2023-10-23 01:57:41, 0:00:30
# 2023-10-23 01:57:42,166 WARNING  pid:6164 util:139:enumerateWithEstimate E310 Training ----/203, done at 2023-10-23 01:57:42
# 2023-10-23 01:57:42,166 INFO     pid:6164 __main__:381:logMetrics E310 SegmentationTrainingApp
# 2023-10-23 01:57:42,166 INFO     pid:6164 __main__:411:logMetrics E310 trn      1.0651 loss, 0.0908 precision, 0.9912 recall, 0.1664 f1 score
# 2023-10-23 01:57:42,166 INFO     pid:6164 __main__:421:logMetrics E310 trn_all  1.0651 loss,  99.1% tp,   0.9% fn,     992.2% fp
# 2023-10-23 01:57:42,182 WARNING  pid:6164 util:109:enumerateWithEstimate E310 Validation  ----/17, starting
# 2023-10-23 01:58:04,556 INFO     pid:6164 util:126:enumerateWithEstimate E310 Validation    16/17, done at 2023-10-23 01:58:04, 0:00:02
# 2023-10-23 01:58:05,358 WARNING  pid:6164 util:139:enumerateWithEstimate E310 Validation  ----/17, done at 2023-10-23 01:58:05
# 2023-10-23 01:58:05,359 INFO     pid:6164 __main__:381:logMetrics E310 SegmentationTrainingApp
# 2023-10-23 01:58:05,359 INFO     pid:6164 __main__:411:logMetrics E310 val      1.1652 loss, 0.0432 precision, 0.4387 recall, 0.0787 f1 score
# 2023-10-23 01:58:05,359 INFO     pid:6164 __main__:421:logMetrics E310 val_all  1.1652 loss,  43.9% tp,  56.1% fn,     971.2% fp
# 2023-10-23 01:58:05,387 INFO     pid:6164 __main__:474:saveModel Saved model params to models\udet\seg_2023-10-22_20.26.06_final-cls.502820.state
# 2023-10-23 01:58:05,396 INFO     pid:6164 __main__:486:saveModel SHA1: 62d557e15a8556278da4db870b0d05372fc968c2
# 2023-10-23 01:58:57,460 INFO     pid:6164 __main__:187:main Epoch 311 of 400, 203/17 batches of size 8*1
# 2023-10-23 01:58:57,498 WARNING  pid:6164 util:109:enumerateWithEstimate E311 Training ----/203, starting
# 2023-10-23 01:59:25,144 INFO     pid:6164 util:126:enumerateWithEstimate E311 Training   64/203, done at 2023-10-23 01:59:46, 0:00:30
# 2023-10-23 01:59:47,145 WARNING  pid:6164 util:139:enumerateWithEstimate E311 Training ----/203, done at 2023-10-23 01:59:47
# 2023-10-23 01:59:47,145 INFO     pid:6164 __main__:381:logMetrics E311 SegmentationTrainingApp
# 2023-10-23 01:59:47,145 INFO     pid:6164 __main__:411:logMetrics E311 trn      1.0610 loss, 0.0885 precision, 0.9885 recall, 0.1625 f1 score
# 2023-10-23 01:59:47,145 INFO     pid:6164 __main__:421:logMetrics E311 trn_all  1.0610 loss,  98.9% tp,   1.1% fn,    1018.1% fp
# 2023-10-23 01:59:47,153 INFO     pid:6164 __main__:187:main Epoch 312 of 400, 203/17 batches of size 8*1
# 2023-10-23 01:59:47,171 WARNING  pid:6164 util:109:enumerateWithEstimate E312 Training ----/203, starting
# 2023-10-23 02:00:09,132 INFO     pid:6164 util:126:enumerateWithEstimate E312 Training   64/203, done at 2023-10-23 02:00:30, 0:00:30
# 2023-10-23 02:00:31,158 WARNING  pid:6164 util:139:enumerateWithEstimate E312 Training ----/203, done at 2023-10-23 02:00:31
# 2023-10-23 02:00:31,158 INFO     pid:6164 __main__:381:logMetrics E312 SegmentationTrainingApp
# 2023-10-23 02:00:31,158 INFO     pid:6164 __main__:411:logMetrics E312 trn      1.0620 loss, 0.0935 precision, 0.9923 recall, 0.1710 f1 score
# 2023-10-23 02:00:31,158 INFO     pid:6164 __main__:421:logMetrics E312 trn_all  1.0620 loss,  99.2% tp,   0.8% fn,     961.7% fp
# 2023-10-23 02:00:31,172 INFO     pid:6164 __main__:187:main Epoch 313 of 400, 203/17 batches of size 8*1
# 2023-10-23 02:00:31,196 WARNING  pid:6164 util:109:enumerateWithEstimate E313 Training ----/203, starting
# 2023-10-23 02:00:52,804 INFO     pid:6164 util:126:enumerateWithEstimate E313 Training   64/203, done at 2023-10-23 02:01:13, 0:00:29
# 2023-10-23 02:01:14,318 WARNING  pid:6164 util:139:enumerateWithEstimate E313 Training ----/203, done at 2023-10-23 02:01:14
# 2023-10-23 02:01:14,319 INFO     pid:6164 __main__:381:logMetrics E313 SegmentationTrainingApp
# 2023-10-23 02:01:14,320 INFO     pid:6164 __main__:411:logMetrics E313 trn      1.0606 loss, 0.1028 precision, 0.9925 recall, 0.1864 f1 score
# 2023-10-23 02:01:14,320 INFO     pid:6164 __main__:421:logMetrics E313 trn_all  1.0606 loss,  99.2% tp,   0.8% fn,     865.9% fp
# 2023-10-23 02:01:14,322 INFO     pid:6164 __main__:187:main Epoch 314 of 400, 203/17 batches of size 8*1
# 2023-10-23 02:01:14,346 WARNING  pid:6164 util:109:enumerateWithEstimate E314 Training ----/203, starting
# 2023-10-23 02:01:36,264 INFO     pid:6164 util:126:enumerateWithEstimate E314 Training   64/203, done at 2023-10-23 02:01:57, 0:00:30
# 2023-10-23 02:01:58,296 WARNING  pid:6164 util:139:enumerateWithEstimate E314 Training ----/203, done at 2023-10-23 02:01:58
# 2023-10-23 02:01:58,297 INFO     pid:6164 __main__:381:logMetrics E314 SegmentationTrainingApp
# 2023-10-23 02:01:58,298 INFO     pid:6164 __main__:411:logMetrics E314 trn      1.0539 loss, 0.1142 precision, 0.9934 recall, 0.2048 f1 score
# 2023-10-23 02:01:58,298 INFO     pid:6164 __main__:421:logMetrics E314 trn_all  1.0539 loss,  99.3% tp,   0.7% fn,     770.6% fp
# 2023-10-23 02:01:58,300 INFO     pid:6164 __main__:187:main Epoch 315 of 400, 203/17 batches of size 8*1
# 2023-10-23 02:01:58,317 WARNING  pid:6164 util:109:enumerateWithEstimate E315 Training ----/203, starting
# 2023-10-23 02:02:20,102 INFO     pid:6164 util:126:enumerateWithEstimate E315 Training   64/203, done at 2023-10-23 02:02:41, 0:00:30
# 2023-10-23 02:02:42,085 WARNING  pid:6164 util:139:enumerateWithEstimate E315 Training ----/203, done at 2023-10-23 02:02:42
# 2023-10-23 02:02:42,085 INFO     pid:6164 __main__:381:logMetrics E315 SegmentationTrainingApp
# 2023-10-23 02:02:42,085 INFO     pid:6164 __main__:411:logMetrics E315 trn      1.0610 loss, 0.0824 precision, 0.9864 recall, 0.1520 f1 score
# 2023-10-23 02:02:42,085 INFO     pid:6164 __main__:421:logMetrics E315 trn_all  1.0610 loss,  98.6% tp,   1.4% fn,    1099.2% fp
# 2023-10-23 02:02:42,097 WARNING  pid:6164 util:109:enumerateWithEstimate E315 Validation  ----/17, starting
# 2023-10-23 02:03:04,578 INFO     pid:6164 util:126:enumerateWithEstimate E315 Validation    16/17, done at 2023-10-23 02:03:04, 0:00:02
# 2023-10-23 02:03:05,450 WARNING  pid:6164 util:139:enumerateWithEstimate E315 Validation  ----/17, done at 2023-10-23 02:03:05
# 2023-10-23 02:03:05,450 INFO     pid:6164 __main__:381:logMetrics E315 SegmentationTrainingApp
# 2023-10-23 02:03:05,450 INFO     pid:6164 __main__:411:logMetrics E315 val      1.1659 loss, 0.0296 precision, 0.4440 recall, 0.0555 f1 score
# 2023-10-23 02:03:05,450 INFO     pid:6164 __main__:421:logMetrics E315 val_all  1.1659 loss,  44.4% tp,  55.6% fn,    1454.9% fp
# 2023-10-23 02:03:05,480 INFO     pid:6164 __main__:474:saveModel Saved model params to models\udet\seg_2023-10-22_20.26.06_final-cls.510930.state
# 2023-10-23 02:03:05,487 INFO     pid:6164 __main__:486:saveModel SHA1: 76c4f8291a8b10cfa40d6c9e61191a993e784341
# 2023-10-23 02:03:56,895 INFO     pid:6164 __main__:187:main Epoch 316 of 400, 203/17 batches of size 8*1
# 2023-10-23 02:03:56,931 WARNING  pid:6164 util:109:enumerateWithEstimate E316 Training ----/203, starting
# 2023-10-23 02:04:24,657 INFO     pid:6164 util:126:enumerateWithEstimate E316 Training   64/203, done at 2023-10-23 02:04:45, 0:00:30
# 2023-10-23 02:04:46,673 WARNING  pid:6164 util:139:enumerateWithEstimate E316 Training ----/203, done at 2023-10-23 02:04:46
# 2023-10-23 02:04:46,673 INFO     pid:6164 __main__:381:logMetrics E316 SegmentationTrainingApp
# 2023-10-23 02:04:46,673 INFO     pid:6164 __main__:411:logMetrics E316 trn      1.0632 loss, 0.0876 precision, 0.9913 recall, 0.1610 f1 score
# 2023-10-23 02:04:46,673 INFO     pid:6164 __main__:421:logMetrics E316 trn_all  1.0632 loss,  99.1% tp,   0.9% fn,    1032.1% fp
# 2023-10-23 02:04:46,679 INFO     pid:6164 __main__:187:main Epoch 317 of 400, 203/17 batches of size 8*1
# 2023-10-23 02:04:46,702 WARNING  pid:6164 util:109:enumerateWithEstimate E317 Training ----/203, starting
# 2023-10-23 02:05:08,482 INFO     pid:6164 util:126:enumerateWithEstimate E317 Training   64/203, done at 2023-10-23 02:05:29, 0:00:30
# 2023-10-23 02:05:30,477 WARNING  pid:6164 util:139:enumerateWithEstimate E317 Training ----/203, done at 2023-10-23 02:05:30
# 2023-10-23 02:05:30,477 INFO     pid:6164 __main__:381:logMetrics E317 SegmentationTrainingApp
# 2023-10-23 02:05:30,477 INFO     pid:6164 __main__:411:logMetrics E317 trn      1.0611 loss, 0.0858 precision, 0.9890 recall, 0.1578 f1 score
# 2023-10-23 02:05:30,477 INFO     pid:6164 __main__:421:logMetrics E317 trn_all  1.0611 loss,  98.9% tp,   1.1% fn,    1054.4% fp
# 2023-10-23 02:05:30,484 INFO     pid:6164 __main__:187:main Epoch 318 of 400, 203/17 batches of size 8*1
# 2023-10-23 02:05:30,504 WARNING  pid:6164 util:109:enumerateWithEstimate E318 Training ----/203, starting
# 2023-10-23 02:05:52,429 INFO     pid:6164 util:126:enumerateWithEstimate E318 Training   64/203, done at 2023-10-23 02:06:13, 0:00:30
# 2023-10-23 02:06:14,429 WARNING  pid:6164 util:139:enumerateWithEstimate E318 Training ----/203, done at 2023-10-23 02:06:14
# 2023-10-23 02:06:14,429 INFO     pid:6164 __main__:381:logMetrics E318 SegmentationTrainingApp
# 2023-10-23 02:06:14,429 INFO     pid:6164 __main__:411:logMetrics E318 trn      1.0530 loss, 0.0971 precision, 0.9923 recall, 0.1768 f1 score
# 2023-10-23 02:06:14,429 INFO     pid:6164 __main__:421:logMetrics E318 trn_all  1.0530 loss,  99.2% tp,   0.8% fn,     923.0% fp
# 2023-10-23 02:06:14,431 INFO     pid:6164 __main__:187:main Epoch 319 of 400, 203/17 batches of size 8*1
# 2023-10-23 02:06:14,454 WARNING  pid:6164 util:109:enumerateWithEstimate E319 Training ----/203, starting
# 2023-10-23 02:06:36,378 INFO     pid:6164 util:126:enumerateWithEstimate E319 Training   64/203, done at 2023-10-23 02:06:57, 0:00:30
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 SegmentationTrainingApp(sys_argv=['--epochs=400','--augmented', 'final-cls',"--num-workers=8", "--batch-size=8"]).main()
#
# Cell In[7], line 196, in SegmentationTrainingApp.main(self)
#     186 for epoch_ndx in range(1, self.cli_args.epochs + 1):
#     187     log.info("Epoch {} of {}, {}/{} batches of size {}*{}".format(
#     188         epoch_ndx,
#     189         self.cli_args.epochs,
#    (...)
#     193         (torch.cuda.device_count() if self.use_cuda else 1),
#     194     ))
# --> 196     trnMetrics_t = self.doTraining(epoch_ndx, train_dl)
#     197     self.logMetrics(epoch_ndx, 'trn', trnMetrics_t)
#     199     if epoch_ndx == 1 or epoch_ndx % self.validation_cadence == 0:
#     200         # if validation is wanted
#
# Cell In[7], line 226, in SegmentationTrainingApp.doTraining(self, epoch_ndx, train_dl)
#     223 for batch_ndx, batch_tup in batch_iter:
#     224     self.optimizer.zero_grad()
# --> 226     loss_var = self.computeBatchLoss(batch_ndx, batch_tup, train_dl.batch_size, trnMetrics_g)
#     227     loss_var.backward()
#     229     self.optimizer.step()
#
# Cell In[7], line 257, in SegmentationTrainingApp.computeBatchLoss(self, batch_ndx, batch_tup, batch_size, metrics_g, classificationThreshold)
#     254 label_g = label_t.to(self.device, non_blocking=True)
#     256 if self.segmentation_model.training and self.augmentation_dict:
# --> 257     input_g, label_g = self.augmentation_model(input_g, label_g)
#     259 prediction_g = self.segmentation_model(input_g)
#     261 pos_weight = torch.tensor([1000.0]).to(self.device, non_blocking=True)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[4], line 96, in SegmentationAugmentation.forward(self, input_g, label_g)
#      94 transform_t = self._build2dTransformMatrix()
#      95 transform_t = transform_t.expand(input_g.shape[0], -1, -1)  #對Index複製
# ---> 96 transform_t = transform_t.to(input_g.device, torch.float32) #transform前兩行有關伸縮旋轉，最後一行有關平移
#      97 affine_t = F.affine_grid(transform_t[:,:2],
#      98         input_g.size(), align_corners=False)  #使用affine grid的原因是因為用grid可以減少對整張圖的運算量
#      99                              #而且如果用原圖，可能會造成座標落在非整數格上，如此會讓圖型產生矩齒狀
#
# KeyboardInterrupt:

# %%
# %tensorboard --logdir E:\LUNA\nodule_detection\runs\p2ch13\2023-08-17_12.51.58_val_seg_final-cls

# %%
# import os
# os.getcwd()

# %%
# run('p2ch13.training.SegmentationTrainingApp', f'--epochs={final_epochs}', '--augmented', 'final-cls')

# %%
# SegmentationTrainingApp(sys_argv=['--epochs=1','--augmented', 'final-cls']).main()
